# %%
import sqlite3

path = ''
db_name = 'repository.db'

try:
        
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL(RDBを操作するための言語)カーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # テーブルの作成
    sql = 'CREATE TABLE rep (name TEXT, language TEXT, star INT);'

    # SQLの実行
    cur.execute(sql)

except sqlite3.Error as e:
    print('エラーが発生しました:', e)

finally:
    # DBへの接続を閉じる
    conn.close()

# %%
# ライブラリを読み込む
import requests
from bs4 import BeautifulSoup
import time

# 結果を保存するリスト
repositories = []

# Google組織のリポジトリ一覧ページ
base_url = "https://github.com/orgs/google/repositories"
print(f"アクセス先: {base_url}")

# より詳細なヘッダーを設定
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'ja,en-US;q=0.9,en;q=0.8',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Cache-Control': 'max-age=0'
}

# セッションを使用
session = requests.Session()
session.headers.update(headers)

# ページ番号を変えながらリポジトリを取得する
page = 1
max_pages = 94  

while page <= max_pages:
    # base_url(https://github.com/orgs/google/repositories)からページを変更しながら全ページを訪れる
    if page == 1:
        url = f"{base_url}?tab=repositories"
    else:
        url = f"{base_url}?page={page}&tab=repositories"
    
    print(f"\n[ページ {page}] {url}")
    
    try:
        # ページにアクセス
        res = session.get(url, timeout=15)
        
        print(f"  ステータスコード: {res.status_code}")
        
        if res.status_code == 503:
            print("  503エラー")
            time.sleep(5)
            # リトライ
            res = session.get(url, timeout=15)
            print(f"  再試行後のステータスコード: {res.status_code}")
        
        if res.status_code != 200:
            print(f"  アクセスできませんでした。")
            break
        
        res.encoding = 'utf-8'
        soup = BeautifulSoup(res.content, 'html.parser')
        
        # リポジトリのリスト項目を取得
        repo_items = soup.find_all('li', class_='ListItem-module__listItem--k4eMk')
        
        # 別のクラス名も試す
        if not repo_items:
            repo_items = soup.find_all('li', {'data-testid': lambda x: x and 'repository' in str(x).lower()})
        
        if not repo_items:
            # より広い範囲で検索
            repo_items = soup.find_all('li')
            # リポジトリ名を含むものだけフィルター
            repo_items = [item for item in repo_items if item.find('a', href=lambda x: x and '/google/' in str(x))]
        
        if not repo_items:
            print("  リポジトリが見つかりませんでした")
            # HTMLの一部を表示してデバッグ
            print("  HTMLの最初の500文字:")
            print(soup.text[:500])
            break
        
        print(f"  ✓ {len(repo_items)}個のリポジトリ要素を発見")
        
        for item in repo_items:
            # リポジトリ名を取得
            title_h4 = item.find('h4', class_='Title-module__heading--s7YnL')
            if title_h4:
                repo_link = title_h4.find('a', class_='Title-module__anchor--GmXUE')
                if repo_link:
                    repo_name = repo_link.get_text().strip()
                else:
                    continue
            else:
                # 別の方法で探す
                repo_link = item.find('a', href=lambda x: x and x.startswith('/google/'))
                if repo_link:
                    repo_name = repo_link.get_text().strip()
                else:
                    continue
            
            # 言語を取得（いろんな方法を試す）
            language = "不明"
            
            # ReposListItem-module__Text_4--mkG7R クラス（検証より)
            language_span = item.find('span', class_='ReposListItem-module__Text_4--mkG7R')
            if language_span:
                language = language_span.get_text().strip()
            else:
                # itemprop="programmingLanguage"
                language_span = item.find('span', {'itemprop': 'programmingLanguage'})
                if language_span:
                    language = language_span.get_text().strip()
                else:
                    # LanguageCircle の隣のspan
                    lang_circle = item.find('div', class_=lambda x: x and 'LanguageCircle' in str(x))
                    if lang_circle and lang_circle.parent:
                        next_span = lang_circle.find_next_sibling('span')
                        if next_span:
                            language = next_span.get_text().strip()
            
            # スター数を取得（複数の方法を試す）
            star_count = "0"
            
            # aria-labelに"star"を含むaタグ
            star_link = item.find('a', {'aria-label': lambda x: x and 'star' in str(x).lower()})
            if star_link:
                aria_label = star_link.get('aria-label', '')
                # "34 stars" や "1,234 stars" から数字を抽出
                star_count = aria_label.split()[0].replace(',', '')
            else:
                # stargazers へのリンクを探す
                star_link = item.find('a', href=lambda x: x and 'stargazers' in str(x))
                if star_link:
                    # リンクのテキストから数字を取得
                    star_text = star_link.get_text().strip()
                    # カンマを削除
                    star_count = star_text.replace(',', '')
                else:
                    # octicon-star アイコンの隣のテキスト
                    star_svg = item.find('svg', class_='octicon-star')
                    if star_svg and star_svg.parent:
                        # 親要素のテキストからアイコン以外の部分を取得
                        star_text = star_svg.parent.get_text().strip()
                        # 数字だけ抽出
                        import re
                        match = re.search(r'[\d,]+', star_text)
                        if match:
                            star_count = match.group().replace(',', '')
            
            # 結果を保存
            repo_info = {
                'リポジトリ名': repo_name,
                '主要な言語': language,
                'スター数': star_count
            }
            repositories.append(repo_info)
            print(f"    ✓ {repo_name} | {language} | {star_count}")
        
        if len([item for item in repo_items if item.find('a', href=lambda x: x and '/google/' in str(x))]) == 0:
            print(" このページではリポジトリ情報を抽出できませんでした")
        
        # 次のページへ
        page += 1
        
        # サーバーに負荷をかけないため待機
        time.sleep(2)
        
    except Exception as e:
        print(f"  → エラーが発生しました: {e}")
        import traceback
        traceback.print_exc()
        break

# 結果を表示
print("\n" + "="*60)
print(f"取得したリポジトリ数: {len(repositories)}")
print("="*60)

for i, repo in enumerate(repositories[:20], 1):  
    print(f"{i}. {repo['リポジトリ名']}")
    print(f"   言語: {repo['主要な言語']}")
    print(f"   スター: {repo['スター数']}")
    print()
# Out:
# アクセス先: https://github.com/orgs/google/repositories
#
# [ページ 1] https://github.com/orgs/google/repositories?tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ bazel-common | Starlark | 91
#     ✓ XNNPACK | C | 2.2k
#     ✓ osv-scalibr | Go | 536
#     ✓ open-dice | C++ | 26
#     ✓ heir | C++ | 609
#     ✓ dive | C++ | 17
#     ✓ chromium-policy-vulnfeed | Go | 7
#     ✓ site-kit-wp | JavaScript | 1.3k
#     ✓ toucan | C++ | 48
#     ✓ xls | C++ | 1.4k
#     ✓ nomulus | Java | 1.8k
#     ✓ oss-fuzz | Shell | 12k
#     ✓ docsy | JavaScript | 2.9k
#     ✓ tunix | Python | 1.9k
#     ✓ gemma.cpp | C++ | 6.6k
#     ✓ osv-scanner | Go | 8.1k
#     ✓ cassowary.dart | Dart | 44
#     ✓ nsjail | C++ | 3.6k
#     ✓ zerocopy | Rust | 2.1k
#     ✓ flatbuffers | C++ | 25k
#     ✓ dwh-migration-tools | Java | 54
#     ✓ android-cuttlefish | C++ | 571
#     ✓ ink | C++ | 49
#     ✓ or-tools | C++ | 13k
#     ✓ earthengine-catalog | Jsonnet | 121
#     ✓ error-prone | Java | 7.1k
#     ✓ angle | C++ | 3.8k
#     ✓ perfetto | C++ | 5k
#     ✓ oss-fuzz-vulns | Python | 166
#     ✓ skia | C++ | 10k
#
# [ページ 2] https://github.com/orgs/google/repositories?page=2&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ skia-buildbot | Go | 158
#     ✓ device-infra | Java | 58
#     ✓ meridian | Python | 1.2k
#     ✓ gn-language-server | Rust | 18
#     ✓ matr | Rust | 9
#     ✓ dawn | C++ | 778
#     ✓ langfun | Python | 875
#     ✓ osv-scanner-v1 | Go | 2
#     ✓ adk-docs | HTML | 974
#     ✓ quiche | C++ | 801
#     ✓ private-compute-libraries | Kotlin | 34
#     ✓ gson | Java | 24k
#     ✓ kafel | C | 340
#     ✓ adk-python | Python | 16k
#     ✓ mug | Java | 444
#     ✓ biva | C++ | 6
#     ✓ ground-android | Kotlin | 272
#     ✓ gvisor | Go | 17k
#     ✓ budoux-extension | TypeScript | 16
#     ✓ tabuli | C++ | 35
#     ✓ filament | C++ | 19k
#     ✓ adk-go | Go | 4.6k
#     ✓ Xee | Python | 320
#     ✓ safevalues | TypeScript | 137
#     ✓ init2winit | Python | 79
#     ✓ jetpack-camera-app | Kotlin | 276
#     ✓ orbax | Python | 455
#     ✓ eclipsa-audio-plugin | C++ | 56
#     ✓ adk-js | TypeScript | 99
#     ✓ crubit | C++ | 924
#
# [ページ 3] https://github.com/orgs/google/repositories?page=3&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ cel-java | Java | 227
#     ✓ cel-spec | Starlark | 3.5k
#     ✓ nearby | C++ | 887
#     ✓ crosvm | Rust | 1.1k
#     ✓ grain | Python | 602
#     ✓ ground-platform | TypeScript | 227
#     ✓ earthengine-api | JavaScript | 3.1k
#     ✓ closure-compiler | JavaScript | 7.6k
#     ✓ dotprompt | Python | 328
#     ✓ kotlin-fhirpath | Kotlin | 6
#     ✓ bloaty | C++ | 5.3k
#     ✓ civics_cdf_validator | Python | 34
#     ✓ netkat | C++ | 27
#     ✓ koladata | C++ | 27
#     ✓ virtual-printer | Kotlin | 2
#     ✓ garf | Python | 11
#     ✓ benchmark | C++ | 9.9k
#     ✓ digitalbuildings | Python | 424
#     ✓ oracle-toolkit | Shell | 65
#     ✓ fuzztest | C++ | 924
#     ✓ fonts | HTML | 19k
#     ✓ gfxstream | C++ | 21
#     ✓ clusterfuzz | Python | 5.5k
#     ✓ xrblocks | TypeScript | 153
#     ✓ cel-cpp | C++ | 205
#     ✓ closure-templates | Java | 671
#     ✓ TestParameterInjector | Java | 415
#     ✓ sec-gemini | Svelte | 107
#     ✓ secure-aggregation | Rust | 5
#     ✓ security-research | C | 4.3k
#
# [ページ 4] https://github.com/orgs/google/repositories?page=4&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ automotive-design-compose | Rust | 167
#     ✓ dagger | Java | 18k
#     ✓ embardiment | C# | 10
#     ✓ llvm-propeller | C++ | 464
#     ✓ syzkaller | Go | 5.9k
#     ✓ adk-java | Java | 964
#     ✓ ecclesia-machine-management | C++ | 15
#     ✓ zx | JavaScript | 45k
#     ✓ s2geometry | C++ | 2.6k
#     ✓ earthengine-community | Jupyter Notebook | 743
#     ✓ timesketch | Python | 3.2k
#     ✓ yggdrasil-decision-forests | C++ | 621
#     ✓ testrun | Python | 42
#     ✓ dart-neats | Dart | 503
#     ✓ mozc | C++ | 2.8k
#     ✓ highway | C++ | 5.1k
#     ✓ go-querystring | Go | 2.1k
#     ✓ brotli | TypeScript | 14k
#     ✓ googletest-rust | Rust | 393
#     ✓ built_value.dart | Dart | 883
#     ✓ brax | Jupyter Notebook | 2.9k
#     ✓ seesaw | Go | 5.7k
#     ✓ oboe | C++ | 4k
#     ✓ boringssl | C++ | 2.1k
#     ✓ torchax | Python | 130
#     ✓ go-containerregistry | Go | 3.6k
#     ✓ go-units | Go | 7
#     ✓ osv.dev | Python | 2.4k
#     ✓ j2cl | Java | 1.3k
#     ✓ ml-metrics | Python | 19
#
# [ページ 5] https://github.com/orgs/google/repositories?page=5&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ pullsheet | Go | 88
#     ✓ nsscache | Python | 150
#     ✓ adk-samples | Python | 6.4k
#     ✓ tcmalloc | C++ | 5k
#     ✓ aqt | Python | 337
#     ✓ pdl | Rust | 66
#     ✓ mcp-security | Python | 404
#     ✓ oss-rebuild | Go | 669
#     ✓ atheris | Python | 1.5k
#     ✓ adk-python-community | Python | 95
#     ✓ json_serializable.dart | Dart | 1.6k
#     ✓ ksp | Kotlin | 3.3k
#     ✓ qwix | Python | 63
#     ✓ jsonschema-go | Go | 139
#     ✓ gops | Go | 7k
#     ✓ tarpc | Rust | 3.6k
#     ✓ dranet | Go | 146
#     ✓ go-attestation | Go | 404
#     ✓ filonov | Python | 10
#     ✓ libnss-cache | C | 61
#     ✓ assertor | Rust | 144
#     ✓ flax | Jupyter Notebook | 6.9k
#     ✓ clspv | LLVM | 693
#     ✓ langextract | Python | 17k
#     ✓ pack | Rust | 202
#     ✓ gurl | C++ | 0
#     ✓ shell-encryption | C++ | 124
#     ✓ certificate-transparency-go | Go | 1.1k
#     ✓ source_helper.dart | Dart | 16
#     ✓ conscrypt | Java | 1.4k
#
# [ページ 6] https://github.com/orgs/google/repositories?page=6&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ libphonenumber | C++ | 18k
#     ✓ copybara | Java | 2.5k
#     ✓ sentencepiece | C++ | 11k
#     ✓ snappy | C++ | 6.5k
#     ✓ trillian-examples | Go | 173
#     ✓ android-security-lints | Kotlin | 153
#     ✓ secops-wrapper | Python | 44
#     ✓ workflow-graph | TypeScript | 149
#     ✓ android-fhir | Kotlin | 571
#     ✓ silifuzz | C++ | 412
#     ✓ tensorstore | C++ | 1.5k
#     ✓ peoplemath | TypeScript | 128
#     ✓ fscrypt | Go | 982
#     ✓ trillian | Go | 3.7k
#     ✓ go-github | Go | 11k
#     ✓ gke-policy-automation | Go | 525
#     ✓ merchant-api-samples | Java | 10
#     ✓ go-cloud | Go | 9.8k
#     ✓ aoss-verifier | Go | 25
#     ✓ go-jsonnet | Go | 1.8k
#     ✓ certtostore | Go | 96
#     ✓ neuroglancer | TypeScript | 1.2k
#     ✓ minijail | C | 342
#     ✓ osv-scanner-action | Python | 47
#     ✓ jax-datetime | Python | 2
#     ✓ glome | C | 63
#     ✓ gutil | C++ | 11
#     ✓ fleetbench | C++ | 134
#     ✓ across | HTML | 21
#     ✓ scaaml | Python | 175
#
# [ページ 7] https://github.com/orgs/google/repositories?page=7&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ fhir | C++ | 904
#     ✓ horologist | Kotlin | 657
#     ✓ nccl-plugin-gpudirect-tcpxo | C++ | 6
#     ✓ tsl | C++ | 101
#     ✓ gnostic-models | Go | 20
#     ✓ go-sev-guest | Go | 66
#     ✓ fhir-gateway | Java | 90
#     ✓ kotlin | Kotlin | 153
#     ✓ android-beat | 不明 | 2
#     ✓ bumble | Python | 426
#     ✓ gwpsan | C++ | 327
#     ✓ nftables | Go | 1.3k
#     ✓ wasefire | Rust | 127
#     ✓ clasp | TypeScript | 5.3k
#     ✓ guava | Java | 51k
#     ✓ go-tdx-guest | Go | 79
#     ✓ googleapis.dart | Dart | 408
#     ✓ openhtf | Python | 613
#     ✓ github_workflows_playground | 不明 | 8
#     ✓ adk-web | TypeScript | 673
#     ✓ gce-tcb-verifier | Go | 22
#     ✓ github-team | Shell | 2
#     ✓ pyglove | Python | 699
#     ✓ shaderc | C++ | 2.1k
#     ✓ fhir-data-pipes | Jupyter Notebook | 204
#     ✓ cel-go | Go | 2.8k
#     ✓ arolla | C++ | 23
#     ✓ inverting-proxy | Go | 262
#     ✓ ChromeBrowserEnterprise | C# | 57
#     ✓ travel-impact-model-website | TypeScript | 5
#
# [ページ 8] https://github.com/orgs/google/repositories?page=8&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ learned_optimization | Python | 788
#     ✓ rpmpack | Go | 128
#     ✓ cctz | C++ | 631
#     ✓ weather-tools | Python | 241
#     ✓ schema-dts | TypeScript | 1.1k
#     ✓ foteli | C++ | 5
#     ✓ protobuf.dart | Dart | 558
#     ✓ sedpack | Python | 28
#     ✓ mdbook-i18n-helpers | Rust | 194
#     ✓ deps.dev | Go | 354
#     ✓ tsec | TypeScript | 141
#     ✓ github-sandbox | 不明 | 16
#     ✓ dotguides | TypeScript | 21
#     ✓ aarch64-esr-decoder | Rust | 99
#     ✓ torq | Python | 2
#     ✓ osdfir-infrastructure | Smarty | 171
#     ✓ github_nonpublic_api | Python | 43
#     ✓ libhoth | C | 17
#     ✓ oss-fuzz-gen | Python | 1.3k
#     ✓ auto | Java | 11k
#     ✓ xctestrunner | Python | 153
#     ✓ escapevelocity | Java | 39
#     ✓ postcss-rename | TypeScript | 162
#     ✓ praxis | Python | 190
#     ✓ transit | 不明 | 852
#     ✓ riegeli | C++ | 465
#     ✓ swiftshader | C++ | 2.4k
#     ✓ osdemo | Rust | 8
#     ✓ j2objc | Java | 6k
#     ✓ turbine | Java | 82
#
# [ページ 9] https://github.com/orgs/google/repositories?page=9&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ differential-privacy | Go | 3.3k
#     ✓ caliper | Java | 819
#     ✓ aidl-language | 不明 | 23
#     ✓ selinux-policy-languages | 不明 | 14
#     ✓ pdl-language | 不明 | 26
#     ✓ comprehensive-rust | Rust | 32k
#     ✓ webcrypto.dart | Dart | 97
#     ✓ budoux | Python | 1.5k
#     ✓ pytype | Python | 5k
#     ✓ paxml | Python | 540
#     ✓ renameio | Go | 666
#     ✓ seqio | Python | 589
#     ✓ google-toolbox-for-mac | Objective-C | 1.2k
#     ✓ gtm-session-fetcher | Objective-C | 265
#     ✓ alioth | Rust | 307
#     ✓ iwa-vscode-extension | TypeScript | 3
#     ✓ mobly | Python | 716
#     ✓ project-voice | TypeScript | 49
#     ✓ duet | Python | 24
#     ✓ cro3 | Rust | 49
#     ✓ arb-editor | TypeScript | 56
#     ✓ codeql-action | TypeScript | 0
#     ✓ dfindexeddb | Python | 38
#     ✓ sound-checker | Kotlin | 22
#     ✓ traceviz | TypeScript | 4
#     ✓ etils | Python | 244
#     ✓ labs-prototypes | Jupyter Notebook | 85
#     ✓ vector_math.dart | Dart | 341
#     ✓ pprof | Go | 8.9k
#     ✓ rust-crate-audits | 不明 | 255
#
# [ページ 10] https://github.com/orgs/google/repositories?page=10&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ aarch64-rt | Rust | 17
#     ✓ aside | TypeScript | 392
#     ✓ privacy-sandbox-aggregation-service | Go | 28
#     ✓ rbrotli-enc | Rust | 13
#     ✓ ads-api-report-fetcher | TypeScript | 53
#     ✓ guice | Java | 13k
#     ✓ mobly-bundled-snippets | Java | 54
#     ✓ metrax | Python | 47
#     ✓ magika | Python | 9.8k
#     ✓ symphony-gcp | Python | 1
#     ✓ cameratrapai | Python | 386
#     ✓ ml-compiler-opt | Python | 737
#     ✓ google-cloud-datastore-quadruple | M4 | 2
#     ✓ styleguide | HTML | 39k
#     ✓ array_record | C++ | 123
#     ✓ mobly-android-screen-recorder | Python | 5
#     ✓ certificate-transparency-community-site | HTML | 132
#     ✓ tsunami-security-scanner-plugins | Java | 942
#     ✓ tsunami-security-scanner | Java | 8.5k
#     ✓ keep-sorted | Go | 316
#     ✓ docsy-example | HTML | 537
#     ✓ perf_data_converter | C++ | 331
#     ✓ android-emulator-hypervisor-driver | C | 840
#     ✓ ads_oneshop | Python | 19
#     ✓ EarlGrey | Objective-C | 5.7k
#     ✓ zetasql | C++ | 2.4k
#     ✓ myvibe | 不明 | 4
#     ✓ business_intelligence_group | Jupyter Notebook | 14
#     ✓ mobly-bluetooth-ref-validation | Python | 5
#     ✓ googletest | C++ | 38k
#
# [ページ 11] https://github.com/orgs/google/repositories?page=11&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ cloud-android-orchestration | Go | 58
#     ✓ compile-testing | Java | 715
#     ✓ fhir-py | Python | 94
#     ✓ product_video_ads | TypeScript | 61
#     ✓ xplat | Java | 18
#     ✓ go-tpm | Go | 616
#     ✓ guava-beta-checker | Java | 91
#     ✓ google-authenticator-libpam | C | 1.9k
#     ✓ spatial-media | Python | 2k
#     ✓ jimfs | Java | 2.5k
#     ✓ truth | Java | 2.8k
#     ✓ longfellow-zk | C++ | 983
#     ✓ kernel-research | C++ | 48
#     ✓ bindiff | Java | 2.8k
#     ✓ shifter | Go | 45
#     ✓ cddlconv | TypeScript | 11
#     ✓ coset | Rust | 38
#     ✓ sbom-conformance | Go | 2
#     ✓ starlark-go | Go | 2.6k
#     ✓ GoogleSignIn-iOS | Objective-C | 667
#     ✓ rust_icu | Rust | 128
#     ✓ jsir | C++ | 108
#     ✓ walt | Java | 462
#     ✓ meterstick | Jupyter Notebook | 109
#     ✓ cpu_features | C++ | 2.6k
#     ✓ binexport | C++ | 1.2k
#     ✓ kotlin-fhir | Kotlin | 53
#     ✓ saxml | Python | 146
#     ✓ ever | Jupyter Notebook | 14
#     ✓ sso-offloading | TypeScript | 1
#
# [ページ 12] https://github.com/orgs/google/repositories?page=12&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ kf | Go | 400
#     ✓ vizier | Python | 1.6k
#     ✓ instrumentsToPprof | Go | 52
#     ✓ mozc-devices | C++ | 2.7k
#     ✓ ml_collections | Python | 998
#     ✓ graph-renderer | 不明 | 0
#     ✓ container-explorer | Go | 89
#     ✓ googet | Go | 98
#     ✓ google-api-objectivec-client-for-rest | Objective-C | 830
#     ✓ desugar_jdk_libs | Java | 389
#     ✓ uncertainty-baselines | Python | 1.6k
#     ✓ bt-navi-tests | Python | 5
#     ✓ capslock | Go | 1.1k
#     ✓ go-tpm-tools | C | 271
#     ✓ jax-cfd | Jupyter Notebook | 894
#     ✓ p4-infra | C++ | 1
#     ✓ kotlin_convert | Kotlin | 20
#     ✓ built_collection.dart | Dart | 283
#     ✓ quiver-dart | Dart | 1.1k
#     ✓ pthreadpool | C++ | 22
#     ✓ webkit_inspection_protocol.dart | Dart | 33
#     ✓ semantic-locators | JavaScript | 58
#     ✓ brotli-wheels | 不明 | 10
#     ✓ openintent | 不明 | 33
#     ✓ re2 | C++ | 9.5k
#     ✓ bughunters | 不明 | 139
#     ✓ filament-assets | Mathematica | 1
#     ✓ xarray-beam | Python | 158
#     ✓ gsocguides | CSS | 475
#     ✓ mpact-cheriot | C++ | 6
#
# [ページ 13] https://github.com/orgs/google/repositories?page=13&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ glazier | Python | 1.2k
#     ✓ mpact-riscv | C++ | 26
#     ✓ tfp-causalimpact | Python | 135
#     ✓ fscryptctl | C | 137
#     ✓ capirca | Python | 839
#     ✓ imt | C++ | 5
#     ✓ neper | C | 318
#     ✓ autofdo | C++ | 575
#     ✓ ARC-GEN | Python | 33
#     ✓ fresnel | Go | 55
#     ✓ dart_cli_pkg | Dart | 61
#     ✓ fiddle | Python | 364
#     ✓ elemental2 | Java | 167
#     ✓ jsinterop-base | Java | 72
#     ✓ jsinterop-annotations | Java | 21
#     ✓ jsinterop-generator | Java | 82
#     ✓ genie-for-sap-abap-ai-assistant-sample | ABAP | 26
#     ✓ omaha-client | Rust | 6
#     ✓ sbat-rs | Rust | 18
#     ✓ authenticode-rs | Rust | 30
#     ✓ gpt-disk-rs | Rust | 71
#     ✓ hackable_diffusion | Python | 24
#     ✓ zimtohrli | Jupyter Notebook | 172
#     ✓ uri.dart | Dart | 80
#     ✓ mangle | Go | 2.9k
#     ✓ mono_repo.dart | Dart | 165
#     ✓ python-fire | Python | 28k
#     ✓ ragvis | 不明 | 1
#     ✓ xarray-tensorstore | Python | 61
#     ✓ flogger | Java | 1.5k
#
# [ページ 14] https://github.com/orgs/google/repositories?page=14&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ breakpad | C++ | 2.8k
#     ✓ hotels-template-library | C++ | 24
#     ✓ google-ctf | Python | 4.8k
#     ✓ process_runner | Dart | 20
#     ✓ nsync | C | 1.2k
#     ✓ quic-trace | C++ | 119
#     ✓ temporian | Python | 703
#     ✓ mtail | Go | 4k
#     ✓ obr | C++ | 22
#     ✓ turbinia | Python | 777
#     ✓ google-java-format | Java | 6k
#     ✓ addlicense | Go | 850
#     ✓ GoogleAppMeasurement | Swift | 31
#     ✓ rrg | Rust | 59
#     ✓ evt-air-risk-aiaa-scitech-2026 | Python | 2
#     ✓ watchface | Kotlin | 52
#     ✓ double-conversion | C++ | 1.2k
#     ✓ der-ascii | Go | 248
#     ✓ inject-common | Java | 11
#     ✓ jaxite | Python | 88
#     ✓ airio | Python | 21
#     ✓ buzzer | Go | 467
#     ✓ jpegli | C++ | 277
#     ✓ ts-bridge | Go | 54
#     ✓ slo-generator | Python | 546
#     ✓ autobound | Python | 363
#     ✓ pdsl-xray | Java | 2
#     ✓ test-server | Go | 17
#     ✓ sbsim | Python | 86
#     ✓ tracey | Go | 6
#
# [ページ 15] https://github.com/orgs/google/repositories?page=15&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ smbios-validation-tool | Go | 12
#     ✓ pmax_best_practices_dashboard | Shell | 52
#     ✓ pubmed-rag | Jupyter Notebook | 11
#     ✓ loudness_ebur128 | C++ | 3
#     ✓ python-proto-converter | Python | 15
#     ✓ pathways-job | Go | 15
#     ✓ humanio | JavaScript | 14
#     ✓ anonymous-tokens | C++ | 58
#     ✓ eDistantObject | Objective-C | 176
#     ✓ fleetspeak | Go | 142
#     ✓ yamlfmt | Go | 1.6k
#     ✓ tf-shell | Python | 9
#     ✓ rootcanal | C++ | 30
#     ✓ skcms | 不明 | 3
#     ✓ deepvariant | Python | 3.6k
#     ✓ drjax | Python | 15
#     ✓ jaxloop | Jupyter Notebook | 18
#     ✓ private-join-and-compute | C++ | 833
#     ✓ gnxi | Python | 282
#     ✓ winops | Go | 121
#     ✓ intellij-community | Java | 12
#     ✓ wireit | TypeScript | 6.3k
#     ✓ aarch64-paging | Rust | 38
#     ✓ synopsys-dw-uart | Rust | 1
#     ✓ command-fds | Rust | 41
#     ✓ OpenSK | Rust | 3.2k
#     ✓ capsem | Python | 0
#     ✓ private-membership | C++ | 49
#     ✓ yapf | Python | 14k
#     ✓ rune | C | 1.9k
#
# [ページ 16] https://github.com/orgs/google/repositories?page=16&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ trillian-website | HTML | 12
#     ✓ vanir | Python | 342
#     ✓ cabbie | Go | 99
#     ✓ travel-impact-model | 不明 | 164
#     ✓ sandboxed-api | C++ | 1.7k
#     ✓ deepsomatic | 不明 | 275
#     ✓ licenseclassifier | Go | 339
#     ✓ distbench | C++ | 54
#     ✓ ide-perf | Kotlin | 65
#     ✓ native-pkcs11 | Rust | 64
#     ✓ mpact-sim | C++ | 37
#     ✓ webview-ads | HTML | 1
#     ✓ gematria | Python | 91
#     ✓ taxinomia | Go | 1
#     ✓ opendocs | 不明 | 199
#     ✓ jaxopt | Python | 1k
#     ✓ threat-team | YARA | 54
#     ✓ generative-ai-docs | Jupyter Notebook | 2.2k
#     ✓ oss-policies-info | 不明 | 28
#     ✓ cloud-forensics-utils | Python | 489
#     ✓ play-unreal-engine-plugin | C++ | 12
#     ✓ security-testbeds | Tcl | 52
#     ✓ amber | C++ | 214
#     ✓ proto-lens | Haskell | 497
#     ✓ play-services-plugins | Java | 503
#     ✓ packetdrill | C | 950
#     ✓ codemirror.dart | Dart | 87
#     ✓ emboss | Python | 82
#     ✓ playground-elements | TypeScript | 625
#     ✓ snippet-uiautomator | Java | 46
#
# [ページ 17] https://github.com/orgs/google/repositories?page=17&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ slowjam | HTML | 252
#     ✓ fswalker | Go | 109
#     ✓ sanitizers | C | 12k
#     ✓ reflectable.dart | Dart | 382
#     ✓ private-compute-services | Java | 531
#     ✓ llm-sidebar-with-context | JavaScript | 4
#     ✓ mediapy | Jupyter Notebook | 440
#     ✓ learn-oss-with-google | Python | 43
#     ✓ google.github.io | HTML | 533
#     ✓ minimalloc | C++ | 175
#     ✓ smccc | Rust | 8
#     ✓ s2a-proto | 不明 | 0
#     ✓ s2a-go | Go | 25
#     ✓ GoogleUtilities | Objective-C | 121
#     ✓ mount-zip | C++ | 221
#     ✓ dnsmasq_exporter | Go | 184
#     ✓ libultrahdr | C++ | 263
#     ✓ GTMAppAuth | Swift | 413
#     ✓ ffn | Python | 339
#     ✓ trax | Python | 8.3k
#     ✓ mobly-wifi | Python | 7
#     ✓ CausalImpact | R | 1.8k
#     ✓ create-service-account | Python | 25
#     ✓ wmt-mqm-human-evaluation | 不明 | 96
#     ✓ polymorphicDSL | Java | 12
#     ✓ apitools | Python | 145
#     ✓ flink-connector-gcp | Java | 12
#     ✓ bundletool | Java | 3.9k
#     ✓ rdma-unit-test | C++ | 30
#     ✓ GiftStick | Python | 142
#
# [ページ 18] https://github.com/orgs/google/repositories?page=18&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ minja | C++ | 198
#     ✓ gin-config | Python | 2.1k
#     ✓ quahog | Go | 2
#     ✓ sagetv | Java | 280
#     ✓ protobuf-gradle-plugin | Groovy | 1.8k
#     ✓ struct2tensor | Python | 34
#     ✓ material-design-icons | 不明 | 53k
#     ✓ closure-compiler-npm | JavaScript | 339
#     ✓ allocation-instrumenter | Java | 487
#     ✓ draco | C++ | 7k
#     ✓ jscin | JavaScript | 45
#     ✓ kati | Rust | 994
#     ✓ GoogleDataTransport | Objective-C | 53
#     ✓ cql | Go | 94
#     ✓ interop-ios-for-google-sdks | Objective-C | 13
#     ✓ app-check | Objective-C | 31
#     ✓ fully-homomorphic-encryption | C++ | 3.6k
#     ✓ strict-csp | TypeScript | 48
#     ✓ jaxonnxruntime | Python | 125
#     ✓ subcommands | Go | 784
#     ✓ ukey2 | Java | 48
#     ✓ dataflow-ml-starter | Python | 24
#     ✓ async-request-dispatcher-rs | Rust | 3
#     ✓ virtual-broadcast-production-assistant | JavaScript | 17
#     ✓ honggfuzz | C | 3.3k
#     ✓ kctf | Go | 731
#     ✓ gcp_scanner | Python | 341
#     ✓ bigwheels | C++ | 101
#     ✓ web-game-samples | JavaScript | 59
#     ✓ fleetspeak-rs | Rust | 10
#
# [ページ 19] https://github.com/orgs/google/repositories?page=19&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ eng-edu | Jupyter Notebook | 734
#     ✓ edward2 | Jupyter Notebook | 702
#     ✓ fuse-archive | C++ | 223
#     ✓ github-webhook-pubsub-bridge | Go | 6
#     ✓ safe-mmio | Rust | 17
#     ✓ percore | Rust | 8
#     ✓ go-licenses | Go | 961
#     ✓ pybind11clif | C++ | 70
#     ✓ shaderc-rs | Rust | 282
#     ✓ closure-net | 不明 | 3
#     ✓ rax | Python | 335
#     ✓ go-dap | Go | 133
#     ✓ distributed_point_functions | C++ | 77
#     ✓ rust-scudo | Rust | 59
#     ✓ casimir | Rust | 1
#     ✓ ota-analyzer | JavaScript | 13
#     ✓ crumbles | Java | 5
#     ✓ tuple.dart | Dart | 194
#     ✓ grinder.dart | Dart | 266
#     ✓ webdriver.dart | Dart | 141
#     ✓ sync_http.dart | Dart | 17
#     ✓ flutter-mediapipe | Dart | 270
#     ✓ dart-basics | Dart | 164
#     ✓ genc | C++ | 63
#     ✓ carfac | Jupyter Notebook | 131
#     ✓ kube-startup-cpu-boost | Go | 508
#     ✓ jni-bind | C++ | 304
#     ✓ autocxx | Rust | 2.5k
#     ✓ ghc-source-gen | Haskell | 99
#     ✓ tsunami-security-scanner-callback-server | Java | 18
#
# [ページ 20] https://github.com/orgs/google/repositories?page=20&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ partner-ads-experience | 不明 | 4
#     ✓ fast-isotropic-median-filter | C++ | 16
#     ✓ ink-stroke-modeler | C++ | 104
#     ✓ cad_campaign_anomaly_detector | JavaScript | 11
#     ✓ pcie_lmt | Go | 7
#     ✓ llvm-memprof | C++ | 4
#     ✓ soql-tool | Apex | 0
#     ✓ pl011-uart | Rust | 6
#     ✓ saif-data | 不明 | 4
#     ✓ link-diver | TypeScript | 69
#     ✓ wire | Go | 14k
#     ✓ grpc-binary | Swift | 10
#     ✓ kunit-docs | HTML | 29
#     ✓ evolve-forms | Apex | 175
#     ✓ matched_markets | Python | 94
#     ✓ flow-lens | TypeScript | 72
#     ✓ distributed_graph_flow | 不明 | 0
#     ✓ go-eventlog | Go | 15
#     ✓ Serberus | 不明 | 13
#     ✓ node-gles | C++ | 331
#     ✓ co-op-4-all | TypeScript | 10
#     ✓ data-driven-discretization-1d | Jupyter Notebook | 168
#     ✓ howtodiv | Python | 8
#     ✓ corpuscrawler | Python | 211
#     ✓ accompanist | Kotlin | 7.8k
#     ✓ proto-task-queue | Python | 10
#     ✓ arm-gic | Rust | 38
#     ✓ python-spanner-orm | Python | 40
#     ✓ multichase | C | 146
#     ✓ graph-mining | C++ | 712
#
# [ページ 21] https://github.com/orgs/google/repositories?page=21&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ executor.nvim | Lua | 153
#     ✓ s2-geometry-library-java | Java | 578
#     ✓ gnostic | Go | 2.2k
#     ✓ cluster-data | TeX | 1k
#     ✓ speaker-id | Python | 436
#     ✓ localtoast | Go | 114
#     ✓ generative-ai-go | Go | 830
#     ✓ if-this-then-ad | TypeScript | 99
#     ✓ dynamicworld | Jupyter Notebook | 153
#     ✓ effcee | C++ | 102
#     ✓ facade | Python | 134
#     ✓ har2csv | JavaScript | 46
#     ✓ reflow-list | TypeScript | 8
#     ✓ model-viewer | TypeScript | 7.7k
#     ✓ esamplusplus | Python | 4
#     ✓ devlibrary | Vue | 194
#     ✓ shoptimizer | Python | 48
#     ✓ safe-active-record | Ruby | 18
#     ✓ practical-inverse-rendering-of-textured-and-translucent-appearance | Python | 113
#     ✓ deluca | Jupyter Notebook | 124
#     ✓ wci | Python | 36
#     ✓ csv-to-firestore | Python | 25
#     ✓ tacotron | HTML | 540
#     ✓ sequence-layers | Python | 46
#     ✓ conversational-surveys | JavaScript | 6
#     ✓ ippusb | Rust | 4
#     ✓ rubik | Python | 28
#     ✓ vbootrom | C | 16
#     ✓ web-hv | JavaScript | 46
#     ✓ safety-web | TypeScript | 27
#
# [ページ 22] https://github.com/orgs/google/repositories?page=22&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ argh | Rust | 1.9k
#     ✓ fedjax | Python | 266
#     ✓ jsonnet | Jsonnet | 7.4k
#     ✓ chrome-ssh-agent | Go | 274
#     ✓ hrx-ruby | Ruby | 12
#     ✓ smc-hello-world | C | 1
#     ✓ smc-common | C | 1
#     ✓ deku | Go | 6
#     ✓ code-review-bot | Go | 101
#     ✓ truestreet | Go | 42
#     ✓ python-card-framework | Python | 22
#     ✓ ruy | C++ | 316
#     ✓ wuffs | C | 4.7k
#     ✓ gmail-oauth2-tools | Python | 464
#     ✓ triage-party | Go | 521
#     ✓ web-api-gateway | Go | 46
#     ✓ payjs | JavaScript | 7
#     ✓ gonids | Go | 189
#     ✓ flyweights | Rust | 2
#     ✓ litmus | Vue | 38
#     ✓ gtest-parallel | Python | 454
#     ✓ ml-edu | Python | 6
#     ✓ automotive-design-compose-protos | 不明 | 0
#     ✓ swissgl | JavaScript | 1.2k
#     ✓ rde-tester | C++ | 1
#     ✓ refvnli | JavaScript | 0
#     ✓ CoMMA | Rust | 10
#     ✓ fsl-gaming | JavaScript | 25
#     ✓ terraform-google-sqlserver | PowerShell | 3
#     ✓ cost-attribution-solution | HCL | 37
#
# [ページ 23] https://github.com/orgs/google/repositories?page=23&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ lmeval | Python | 235
#     ✓ tachometer | TypeScript | 726
#     ✓ ios-webkit-debug-proxy | C | 6.1k
#     ✓ apilark | 不明 | 6
#     ✓ tcli | Python | 9
#     ✓ app-resource-bundle | 不明 | 155
#     ✓ recaptcha | PHP | 3.5k
#     ✓ ent | Go | 75
#     ✓ CommonLoopUtils | Jupyter Notebook | 358
#     ✓ ebpf-transport-monitoring | Go | 23
#     ✓ rago | Python | 21
#     ✓ aukera | Go | 41
#     ✓ open-location-code | Java | 4.3k
#     ✓ jaxcam | Python | 13
#     ✓ content_recommendation_using_word2vec | Python | 27
#     ✓ safehtml | Go | 373
#     ✓ forest-data-partnership | Jupyter Notebook | 35
#     ✓ lightweight_mmm | Python | 1k
#     ✓ gazoo-device | Python | 23
#     ✓ bt-test-interfaces | Python | 14
#     ✓ avatar | Python | 20
#     ✓ paranoid_crypto | Python | 796
#     ✓ proto-splitter | C++ | 1
#     ✓ cadvisor | Go | 19k
#     ✓ unblocking-detail-caption | HTML | 1
#     ✓ auto-arborist | Jupyter Notebook | 13
#     ✓ qkeras | Python | 578
#     ✓ pts-bot | Rust | 4
#     ✓ vroom | Python | 274
#     ✓ libaddressinput | C++ | 606
#
# [ページ 24] https://github.com/orgs/google/repositories?page=24&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ android-key-attestation | Java | 213
#     ✓ dv360-duplicator | TypeScript | 20
#     ✓ eiffel | C | 5
#     ✓ skyline_rl_lab | Jupyter Notebook | 6
#     ✓ pseudo-identity-provider | Go | 9
#     ✓ llvm-premerge-checks | Python | 43
#     ✓ go-configfs-tsm | Go | 8
#     ✓ grr | Python | 5k
#     ✓ sandwiched_compression | Jupyter Notebook | 48
#     ✓ gemma_pytorch | Python | 5.6k
#     ✓ go-safeweb | Go | 1.5k
#     ✓ visualblocks | TypeScript | 1.3k
#     ✓ codesearch | Go | 3.9k
#     ✓ webauthndemo | TypeScript | 621
#     ✓ UIforETW | C++ | 1.6k
#     ✓ hiba | C | 384
#     ✓ pyink | Python | 280
#     ✓ vk-layer-for-rust | Rust | 14
#     ✓ liblc3 | C | 225
#     ✓ taqo-paco | Dart | 12
#     ✓ jse4conf | Java | 6
#     ✓ synthmark | C++ | 55
#     ✓ df-conformer | HTML | 31
#     ✓ zetasketch | Java | 163
#     ✓ cairn | C++ | 5
#     ✓ agi | Go | 1k
#     ✓ lullaby | C++ | 1.2k
#     ✓ visqol | C++ | 836
#     ✓ glog | C++ | 7.3k
#     ✓ uvq | Python | 119
#
# [ページ 25] https://github.com/orgs/google/repositories?page=25&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ aegis_cipher | C++ | 25
#     ✓ consent-based-conversion-adjustments | Python | 25
#     ✓ containerdbg | C | 74
#     ✓ Stereoscopic-Video-Generation-via-Denoising-Frame-Matrix | Python | 8
#     ✓ iopddl | C++ | 23
#     ✓ badwolf-drivers | Go | 22
#     ✓ project-euphonia-app | Dart | 29
#     ✓ badwolf | Go | 984
#     ✓ fruit | C++ | 1.9k
#     ✓ sa360-bigquery-bootstrapper | Python | 6
#     ✓ gemma-unity-plugin | C# | 79
#     ✓ gemma-journey | C# | 28
#     ✓ feabench | Python | 4
#     ✓ hashr | Go | 126
#     ✓ regexpand | Go | 8
#     ✓ myelin-acorn-electron-hardware | Python | 59
#     ✓ vscode-vnc | TypeScript | 5
#     ✓ pica | Python | 55
#     ✓ strangemeadowlark | Rust | 3
#     ✓ note-maps | Go | 129
#     ✓ curie | Jupyter Notebook | 28
#     ✓ mobly-cros | Python | 2
#     ✓ go-tika | Go | 253
#     ✓ textfsm | Python | 1.2k
#     ✓ sherlock | Python | 8
#     ✓ go-tspi | Go | 62
#     ✓ kernel-sanitizers | Python | 468
#     ✓ file-header | Rust | 19
#     ✓ extra-keyboards-for-chrome-os | JavaScript | 214
#     ✓ libprotobuf-mutator | C++ | 633
#
# [ページ 26] https://github.com/orgs/google/repositories?page=26&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ crc32c | C++ | 498
#     ✓ codeworld | Haskell | 1.3k
#     ✓ smali | Java | 325
#     ✓ android-riscv64 | 不明 | 242
#     ✓ unisim | Python | 144
#     ✓ ml-metadata | C++ | 666
#     ✓ kmsan | C | 417
#     ✓ play-asset-delivery-unity | C# | 13
#     ✓ play-appbundle-unity | C# | 8
#     ✓ file-based-test-driver | C++ | 13
#     ✓ oauth2l | Go | 709
#     ✓ ads-privacy | 不明 | 408
#     ✓ trusted-types-helper | TypeScript | 11
#     ✓ search-in-apps | Swift | 4
#     ✓ eslint-config-google | JavaScript | 1.8k
#     ✓ go-replayers | Go | 432
#     ✓ uVkCompute | C++ | 257
#     ✓ dfdewey | Python | 19
#     ✓ CFU-Playground | Verilog | 535
#     ✓ sqlcommenter | PHP | 616
#     ✓ picatrix | Python | 51
#     ✓ shadertrap | C++ | 12
#     ✓ lldb-eval | C++ | 86
#     ✓ pasta | Python | 359
#     ✓ LogicLM | HTML | 29
#     ✓ wuffs-mirror-release-c | C | 39
#     ✓ image_mix | Python | 16
#     ✓ page-alloc-bench | Go | 4
#     ✓ grizzly | Python | 69
#     ✓ tf-quant-finance | Python | 5.1k
#
# [ページ 27] https://github.com/orgs/google/repositories?page=27&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ coding-with-chrome | JavaScript | 530
#     ✓ html-to-jsonld-converter | Python | 5
#     ✓ gopacket | Go | 6.7k
#     ✓ RB-Modulation | Jupyter Notebook | 402
#     ✓ briolette | Rust | 67
#     ✓ bbr | 不明 | 5.8k
#     ✓ py-lab-hal | Python | 12
#     ✓ bsynth | C++ | 20
#     ✓ .github | 不明 | 109
#     ✓ snowflake-to-bq-data-transfer-tool | Java | 3
#     ✓ password-alert | JavaScript | 322
#     ✓ moodle-on-gcp | Shell | 72
#     ✓ glance-experimental-tools | Kotlin | 185
#     ✓ myanmar-tools | Java | 255
#     ✓ k8s-digester | Go | 155
#     ✓ splice | Go | 65
#     ✓ cc-device-plugin | Go | 4
#     ✓ project-OCEAN | Python | 55
#     ✓ git-pull-request-mirror | Go | 95
#     ✓ weasel | Go | 66
#     ✓ parse-ego4d | Jupyter Notebook | 7
#     ✓ deepconsensus | Python | 252
#     ✓ deeppolisher | Jupyter Notebook | 94
#     ✓ makerspace-auth | Python | 66
#     ✓ material-design-lite | HTML | 32k
#     ✓ patrick | R | 143
#     ✓ xr-objects | C# | 161
#     ✓ dlc-insight-lab | JavaScript | 1
#     ✓ j2cl-protobuf | JavaScript | 25
#     ✓ yarsa | Go | 1
#
# [ページ 28] https://github.com/orgs/google/repositories?page=28&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ googlesre | TypeScript | 167
#     ✓ android-auto-companion-android | Kotlin | 26
#     ✓ automl | Jupyter Notebook | 6.4k
#     ✓ gdb_gcore_point | Python | 2
#     ✓ serde_json5 | Rust | 42
#     ✓ emoji-scavenger-hunt | TypeScript | 819
#     ✓ android-auto-companion-ios | Swift | 16
#     ✓ library-wrapper-unity-common | C# | 7
#     ✓ lottie-tools | Rust | 2
#     ✓ speedy | C++ | 35
#     ✓ pebble | C | 4.9k
#     ✓ volley | Java | 3.4k
#     ✓ open-sztp | Go | 11
#     ✓ pyu2f | Python | 84
#     ✓ marl | C++ | 2k
#     ✓ cppdap | C++ | 182
#     ✓ uem_poc | TypeScript | 3
#     ✓ new-project | 不明 | 234
#     ✓ go-cmp | Go | 4.5k
#     ✓ mlir-hs | Haskell | 118
#     ✓ webrisk | Go | 78
#     ✓ csp-evaluator | TypeScript | 373
#     ✓ multichannel-audio-tools | C++ | 95
#     ✓ pprof-nodejs | JavaScript | 287
#     ✓ hctr2 | C | 37
#     ✓ santa-tracker-web | JavaScript | 644
#     ✓ jira-to-issues | TypeScript | 18
#     ✓ best | Rust | 137
#     ✓ alu-api | Jupyter Notebook | 1
#     ✓ haskell-indexer | Haskell | 101
#
# [ページ 29] https://github.com/orgs/google/repositories?page=29&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ latexify_py | Python | 7.6k
#     ✓ abseil-cpp-binary | Swift | 16
#     ✓ fuzzbench | Python | 1.2k
#     ✓ jarjar | Java | 90
#     ✓ xdtk | Java | 38
#     ✓ play-integrity-unity | C# | 10
#     ✓ play-in-app-reviews-unity | C# | 12
#     ✓ play-in-app-updates-unity | C# | 3
#     ✓ santa | Objective-C++ | 4.5k
#     ✓ play-core-unity | C# | 3
#     ✓ android-auto-companion-app | Dart | 15
#     ✓ orbit | C++ | 4.3k
#     ✓ leveldb | C++ | 38k
#     ✓ ctrdac | Go | 13
#     ✓ mail-importer | Java | 264
#     ✓ deck | Go | 56
#     ✓ unsmear | C++ | 95
#     ✓ library-wrapper-unity-openjdk8 | C# | 7
#     ✓ calblink | Go | 43
#     ✓ kir-holiday-lights | Shell | 19
#     ✓ io-connect-2024-ui-workshop | CSS | 44
#     ✓ snaplayout-for-xmonad | Haskell | 6
#     ✓ dfiq | Python | 294
#     ✓ git-tree | Rust | 45
#     ✓ learn_unsafe_rust | 不明 | 279
#     ✓ archat | TypeScript | 94
#     ✓ summit-ast | Kotlin | 42
#     ✓ rust-p9 | Rust | 43
#     ✓ spiqa | Python | 70
#     ✓ oxsea | Rust | 2
#
# [ページ 30] https://github.com/orgs/google/repositories?page=30&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ re2j | Java | 1.2k
#     ✓ megalista | Python | 138
#     ✓ serde_json_lenient | Rust | 25
#     ✓ bulk-actions-framework | Apex | 1
#     ✓ rag-playground | Python | 41
#     ✓ agi-dev-releases | Shell | 35
#     ✓ fhir-app-examples | Kotlin | 54
#     ✓ shopping_insider | Python | 29
#     ✓ gnostic-grpc | Go | 314
#     ✓ acjs | Go | 10
#     ✓ go-react | Go | 38
#     ✓ broken-dns | Go | 22
#     ✓ xtoproto | Go | 58
#     ✓ martian | Go | 2k
#     ✓ recursive-version-control-system | Go | 31
#     ✓ spdmd | C++ | 0
#     ✓ bulk_fhir_tools | Go | 63
#     ✓ ondc-opencommerce | Go | 24
#     ✓ goblet | Go | 181
#     ✓ webpackager | Go | 75
#     ✓ apt-golang-s3 | Go | 49
#     ✓ fhir-dbt-analytics | Shell | 58
#     ✓ vxsig | C++ | 284
#     ✓ traceur-compiler | JavaScript | 8.2k
#     ✓ vimscript-language-server | Rust | 401
#     ✓ cpp-from-the-sky-down | HTML | 276
#     ✓ tree-math | Python | 202
#     ✓ go-streaming-globber | Go | 6
#     ✓ clusterfuzzlite | 不明 | 509
#     ✓ ads-bi-suite | Shell | 18
#
# [ページ 31] https://github.com/orgs/google/repositories?page=31&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ tcpgpudmarxd | C++ | 9
#     ✓ play-common-unity | C# | 1
#     ✓ play-unity-plugins | C# | 465
#     ✓ codex | Jupyter Notebook | 67
#     ✓ sre_yield | Python | 187
#     ✓ lintush | JavaScript | 59
#     ✓ emoji-segmenter | C | 64
#     ✓ unity-anr-plugin | Java | 5
#     ✓ imageinwords | JavaScript | 223
#     ✓ android-emulator-container-scripts | Python | 2k
#     ✓ werm | C | 46
#     ✓ season-of-docs | 不明 | 579
#     ✓ uuid | Go | 5.9k
#     ✓ android-auto-companion-calendarsync-ios | Swift | 6
#     ✓ ionosphere | Jupyter Notebook | 3
#     ✓ takeout | 不明 | 11
#     ✓ promises | Objective-C | 3.8k
#     ✓ iba-opt-out-plugin | JavaScript | 1
#     ✓ dopamine | Jupyter Notebook | 11k
#     ✓ docci | HTML | 3
#     ✓ compute-virtual-ethernet-dpdk | C | 11
#     ✓ angular-directed-graph | TypeScript | 18
#     ✓ skywater-pdk | Python | 3.3k
#     ✓ safearchive | Go | 64
#     ✓ gts | TypeScript | 5.2k
#     ✓ fuzzing | C++ | 3.7k
#     ✓ slang-gaussian-rasterization | Python | 362
#     ✓ talkback | Java | 488
#     ✓ langsvr | C++ | 9
#     ✓ coroutine-stacks | Kotlin | 144
#
# [ページ 32] https://github.com/orgs/google/repositories?page=32&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ devtools-driver | Java | 16
#     ✓ account-provisioning-for-google-apps | Java | 51
#     ✓ chicago-brick | TypeScript | 161
#     ✓ tour-of-wgsl | TypeScript | 142
#     ✓ crfs | Go | 1.4k
#     ✓ cql-on-beam | Java | 12
#     ✓ capsicum-test | C++ | 45
#     ✓ docker-explorer | Python | 548
#     ✓ graphicsfuzz | Java | 594
#     ✓ CodeCity | JavaScript | 193
#     ✓ moriarty | C++ | 6
#     ✓ uis-rnn | Python | 1.6k
#     ✓ purr | Shell | 155
#     ✓ karma-webkit-launcher | JavaScript | 12
#     ✓ yaml-ui-editor | Java | 32
#     ✓ supl-client | Java | 71
#     ✓ robotstxt-spec-test | Java | 23
#     ✓ step49-2020 | Java | 3
#     ✓ robotstxt-java | Java | 47
#     ✓ exposure-notifications-private-analytics-ingestion | Java | 12
#     ✓ play-work | Java | 85
#     ✓ grr-doc | Shell | 307
#     ✓ eng-practices | 不明 | 20k
#     ✓ tec-web-assignments | JavaScript | 12
#     ✓ webdriver-shadow-dom | Kotlin | 2
#     ✓ drive-file-search-fix | JavaScript | 5
#     ✓ gousb | Go | 919
#     ✓ bayesnf | Python | 142
#     ✓ funke-eudi-wallet-prototype | Kotlin | 3
#     ✓ vimdoc | Python | 304
#
# [ページ 33] https://github.com/orgs/google/repositories?page=33&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ paseos | JavaScript | 15
#     ✓ tsunami | TypeScript | 9
#     ✓ hrx | SCSS | 49
#     ✓ english-- | JavaScript | 7
#     ✓ clif | C++ | 981
#     ✓ grrshell | Python | 7
#     ✓ cdc-file-transfer | C++ | 3.4k
#     ✓ devops-governance | 不明 | 83
#     ✓ google-visualization | TypeScript | 14
#     ✓ price_visibility_booster | JavaScript | 2
#     ✓ vim-codefmt | Vim Script | 1.1k
#     ✓ project-gameface | Java | 617
#     ✓ Vulkan-Errata | Python | 5
#     ✓ ad_language_monitor | JavaScript | 5
#     ✓ cell_img | Jupyter Notebook | 8
#     ✓ souper | C++ | 2.3k
#     ✓ audio-to-tactile | C | 103
#     ✓ secrets-gradle-plugin | Kotlin | 1.3k
#     ✓ madi | Python | 78
#     ✓ google-api-javascript-client | CSS | 3.4k
#     ✓ btree | Go | 4.1k
#     ✓ it-cert-automation-practice | Python | 985
#     ✓ sxg-rs | Rust | 85
#     ✓ lyra | C++ | 3.9k
#     ✓ schemarama | JavaScript | 146
#     ✓ premium-vs-standard-network-latency | Shell | 4
#     ✓ lut3d_utils | Python | 11
#     ✓ rust-derive-fuzztest | Rust | 18
#     ✓ real-time-intelligence-workshop | Jupyter Notebook | 27
#     ✓ ghost-kernel | C | 227
#
# [ページ 34] https://github.com/orgs/google/repositories?page=34&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ ansicolor-dart | Dart | 104
#     ✓ libnop | C++ | 576
#     ✓ zopfli | C++ | 3.6k
#     ✓ flutter.widgets | Dart | 1.4k
#     ✓ lifetime_value | Jupyter Notebook | 365
#     ✓ ExoPlayer | Java | 22k
#     ✓ woff2 | C++ | 1.7k
#     ✓ pwlfit | Jupyter Notebook | 40
#     ✓ haloquest | Jupyter Notebook | 23
#     ✓ robotstxt | C++ | 3.4k
#     ✓ closure-library | JavaScript | 4.9k
#     ✓ omaha | C++ | 2.6k
#     ✓ pycnite | Python | 26
#     ✓ model_search | Python | 3.3k
#     ✓ shopping-markup | Python | 49
#     ✓ resultstoreui | Python | 12
#     ✓ sg2im | Python | 1.3k
#     ✓ namebench | Go | 923
#     ✓ flight-lab | Python | 15
#     ✓ nccl-plugin-gpudirecttcpx | C++ | 14
#     ✓ zazu | TypeScript | 21
#     ✓ codewords | TypeScript | 11
#     ✓ voice-builder | JavaScript | 679
#     ✓ dynamic-form | TypeScript | 30
#     ✓ werewolf_arena | Python | 40
#     ✓ cargo-raze | Rust | 481
#     ✓ safetext | Go | 150
#     ✓ daguerreotype | TypeScript | 9
#     ✓ sgtm-migrator | TypeScript | 17
#     ✓ BIG-bench | Python | 3.2k
#
# [ページ 35] https://github.com/orgs/google/repositories?page=35&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ feedloader | Python | 13
#     ✓ wikiloop-explorer | Vue | 8
#     ✓ nodejs-container-image-builder | TypeScript | 73
#     ✓ node-fastify-auto-push | TypeScript | 101
#     ✓ streetview-publish-client-libraries | Java | 19
#     ✓ defi-for-good-contracts | TypeScript | 14
#     ✓ oodle-demo | HTML | 83
#     ✓ making_with_ml | Jupyter Notebook | 348
#     ✓ centaur | TypeScript | 12
#     ✓ poseshield-tfjs | Vue | 14
#     ✓ personfinder | Python | 540
#     ✓ ai_assisted_display_creative | Python | 16
#     ✓ automated-native-creatives | TypeScript | 16
#     ✓ budoux-illustrator-script | TypeScript | 20
#     ✓ aoss-django-sample-starter-project | Shell | 6
#     ✓ nanopb-podspec | Ruby | 7
#     ✓ setfilters | Java | 10
#     ✓ agamotto | Python | 18
#     ✓ balloon-learning-environment | Python | 125
#     ✓ seatera | Python | 18
#     ✓ diffseg | Jupyter Notebook | 327
#     ✓ window-mirror | C# | 18
#     ✓ keyword_factory | Python | 41
#     ✓ merchant_center_repor_builder | Python | 11
#     ✓ inspiration_tree | Jupyter Notebook | 77
#     ✓ brain-tokyo-workshop | Jupyter Notebook | 1.3k
#     ✓ taxonomy_wizard | Python | 13
#     ✓ mandiant-ti-client | Python | 19
#     ✓ vertex-pipelines-boilerplate | Python | 10
#     ✓ project_cartesian | Python | 20
#
# [ページ 36] https://github.com/orgs/google/repositories?page=36&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ android-emulator-webrtc | JavaScript | 149
#     ✓ password-sync-support-tool | VBScript | 34
#     ✓ jsonapi | Go | 1.4k
#     ✓ ad-manager-alerter | Python | 27
#     ✓ looker-studio-dashboard-cloner | TypeScript | 36
#     ✓ gcp-scc-iac-validation-utils | Go | 2
#     ✓ iconvg | C | 682
#     ✓ playhvz | Kotlin | 26
#     ✓ assetMG | TypeScript | 7
#     ✓ bulkan | TypeScript | 7
#     ✓ evojax | Jupyter Notebook | 925
#     ✓ telluride_decoding | Python | 14
#     ✓ font-go | Go | 54
#     ✓ java-time-client | Java | 18
#     ✓ project-euphonia-audiotool | TypeScript | 27
#     ✓ task-oriented-queries | 不明 | 5
#     ✓ peripheral-customization-pwa | TypeScript | 7
#     ✓ protobuf-extensibility-for-burp | Python | 88
#     ✓ eventid-js | TypeScript | 78
#     ✓ node-h2-auto-push | TypeScript | 328
#     ✓ js-green-licenses | TypeScript | 181
#     ✓ gasket-driver | C | 109
#     ✓ wikiloop-doublecheck | TypeScript | 83
#     ✓ data-layer-helper | JavaScript | 440
#     ✓ dana | JavaScript | 117
#     ✓ accname | TypeScript | 34
#     ✓ libhidtelephony | TypeScript | 12
#     ✓ incremental-dom | TypeScript | 3.5k
#     ✓ pixelate | TypeScript | 54
#     ✓ conversion-audit | TypeScript | 5
#
# [ページ 37] https://github.com/orgs/google/repositories?page=37&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ data-quality-monitor | TypeScript | 38
#     ✓ product-dsa | Python | 12
#     ✓ react-schemaorg | TypeScript | 506
#     ✓ android-management-api-samples | Jupyter Notebook | 34
#     ✓ creative-screenshots | TypeScript | 17
#     ✓ dqm | Python | 27
#     ✓ fusion-tables-archive-visualizer | TypeScript | 33
#     ✓ nodejs-wiki | JavaScript | 17
#     ✓ assortment-quality-for-shopping-ads | Python | 8
#     ✓ eleventy-high-performance-blog | JavaScript | 4.1k
#     ✓ uafcs | Python | 4
#     ✓ vsf-time-series | Python | 30
#     ✓ oculi | Jupyter Notebook | 63
#     ✓ android-uiconductor | Java | 125
#     ✓ tamperchrome | TypeScript | 4.2k
#     ✓ gov-meetings-made-searchable | Python | 33
#     ✓ patents-public-data | Jupyter Notebook | 627
#     ✓ tweakr | JavaScript | 26
#     ✓ ngrx-visualizer | TypeScript | 23
#     ✓ mweb-analysis-tools | JavaScript | 8
#     ✓ fusion-tables-drive-export | TypeScript | 7
#     ✓ vscode-zxdb | TypeScript | 4
#     ✓ gtasks-md | Python | 74
#     ✓ triggerator | TypeScript | 11
#     ✓ service-worker-detector | JavaScript | 183
#     ✓ cronet-transport-for-okhttp | Java | 523
#     ✓ ditto-mocks | Apex | 97
#     ✓ gps-measurement-tools | Java | 803
#     ✓ stijl | JavaScript | 43
#     ✓ schedviz | Go | 530
#
# [ページ 38] https://github.com/orgs/google/repositories?page=38&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ grassland | TypeScript | 10
#     ✓ synthesizer-io | Rust | 36
#     ✓ eslint-closure | JavaScript | 33
#     ✓ intermock | TypeScript | 1.2k
#     ✓ mpact-sim-codelabs | C++ | 4
#     ✓ pybadges | Python | 498
#     ✓ uv-metrics | Python | 13
#     ✓ caliban | Python | 500
#     ✓ verilogpp | Perl | 17
#     ✓ t5patches | Python | 12
#     ✓ vpn-libraries | C++ | 554
#     ✓ go-p11-kit | Go | 93
#     ✓ ngx_brotli | C | 2.2k
#     ✓ psp | C | 276
#     ✓ google-sql-syntax-ts | TypeScript | 9
#     ✓ fishy-pdf | Python | 11
#     ✓ dv360-spend-monitoring-tool | JavaScript | 6
#     ✓ diff-match-patch | Python | 8k
#     ✓ hi-lassie | Python | 24
#     ✓ lassie | Python | 53
#     ✓ lkml-gerrit-bridge | Python | 7
#     ✓ lecam-gan | Jupyter Notebook | 165
#     ✓ prog-edu-assistant | Jupyter Notebook | 33
#     ✓ har-sanitizer | Python | 73
#     ✓ pre-commit-tool-hooks | Python | 38
#     ✓ jsaction | JavaScript | 1.1k
#     ✓ deepmac | HTML | 5
#     ✓ game-changing-assets | Jupyter Notebook | 3
#     ✓ framework-for-osdu | Java | 19
#     ✓ hintless_pir | C++ | 22
#
# [ページ 39] https://github.com/orgs/google/repositories?page=39&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ jwt_verify_lib | C++ | 44
#     ✓ prompt-to-prompt | Jupyter Notebook | 3.4k
#     ✓ how-unique-is-whose-web-browser | Jupyter Notebook | 2
#     ✓ brunsli | C++ | 745
#     ✓ gapid | Go | 2.2k
#     ✓ report2bq | Python | 13
#     ✓ brandometer | Python | 10
#     ✓ ldif | Python | 320
#     ✓ pawn | C++ | 337
#     ✓ empirical_calibration | Jupyter Notebook | 45
#     ✓ shuwa | Python | 143
#     ✓ tabletopaudio-action | TypeScript | 9
#     ✓ hypernerf | Python | 943
#     ✓ importlab | Python | 177
#     ✓ ota-generator | Python | 24
#     ✓ ai_video_dubbing | Python | 50
#     ✓ prefab | Kotlin | 229
#     ✓ starthinker | Python | 173
#     ✓ golden-path-for-app-delivery | Go | 18
#     ✓ ringli | C++ | 11
#     ✓ oatts | JavaScript | 141
#     ✓ web-starter-kit | HTML | google/web-starter-kit's
#     ✓ nerfies | Python | 1.9k
#     ✓ flexbox-layout | Kotlin | 18k
#     ✓ cityhash | Shell | 1.2k
#     ✓ intellij-gn-plugin | Kotlin | 15
#     ✓ safebrowsing | Go | 488
#     ✓ AEUX | JavaScript | 541
#     ✓ highwayhash | C++ | 1.6k
#     ✓ amot | Shell | 3
#
# [ページ 40] https://github.com/orgs/google/repositories?page=40&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ licensecheck | Go | 484
#     ✓ osdetector-gradle-plugin | Java | 116
#     ✓ permhash | Python | 44
#     ✓ flaxformer | Python | 363
#     ✓ GTXiLib | Objective-C | 233
#     ✓ esh | C | 331
#     ✓ quota-monitoring-solution | Java | 52
#     ✓ common-multicloud-runtime | 不明 | 0
#     ✓ cmrt | 不明 | 1
#     ✓ coding-with-chrome-libraries | JavaScript | 24
#     ✓ macops-MOLXPCConnection | Objective-C | 26
#     ✓ macops-MOLAuthenticatingURLSession | Objective-C | 23
#     ✓ macops-molcodesignchecker | Objective-C | 33
#     ✓ macops-molcertificate | Objective-C | 36
#     ✓ example-demos-for-msft-workloads | HCL | 16
#     ✓ python-adb | Python | 1.8k
#     ✓ cronutils | C | 119
#     ✓ dmabuf_importer_helper | C | 1
#     ✓ flutter-desktop-embedding | C++ | 7.1k
#     ✓ Accessibility-Test-Framework-for-Android | Java | 499
#     ✓ devx-tools | Go | 73
#     ✓ php-crc32 | PHP | 186
#     ✓ step197-2020 | Java | 4
#     ✓ adb-sync | Python | 1.1k
#     ✓ mint-line-follower | Python | 3
#     ✓ gps-babel-tower | Python | 8
#     ✓ simhospital | Go | 717
#     ✓ adiantum | C | 477
#     ✓ visionai | Python | 47
#     ✓ xsecurelock | C | 914
#
# [ページ 41] https://github.com/orgs/google/repositories?page=41&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ cel-policy-templates-go | Go | 73
#     ✓ mawfs | Go | 63
#     ✓ distla_core | Python | 3
#     ✓ abstracttext | JavaScript | 78
#     ✓ mobly-snippet-lib | 不明 | 42
#     ✓ skywater-pdk-libs-sky130_fd_pr | 不明 | 28
#     ✓ spdm-accelerator-requirement | 不明 | 2
#     ✓ longbet | C++ | 24
#     ✓ dexmod | Python | 63
#     ✓ space | Python | 155
#     ✓ netbsd-gce | Shell | 41
#     ✓ neural-tangents | Jupyter Notebook | 2.4k
#     ✓ redgrep | C++ | 162
#     ✓ binja-hexagon | Python | 116
#     ✓ hark | 不明 | 9
#     ✓ mobly-windows | Python | 4
#     ✓ tree-sitter-fidl | C | 4
#     ✓ bazel_rules_install | Starlark | 43
#     ✓ putting-dune | Python | 10
#     ✓ hierarchical-state-machine.dart | Dart | 36
#     ✓ casa-android | Kotlin | 270
#     ✓ security-crawl-maze | HTML | 163
#     ✓ cordova-plugin-browsertab | Java | 117
#     ✓ csv2pprof | Go | 2
#     ✓ compact_enc_det | C | 239
#     ✓ grafika | Java | 6.1k
#     ✓ gwtmockito | Java | 160
#     ✓ navi | Jupyter Notebook | 59
#     ✓ eidos-audition | C++ | 33
#     ✓ alligator2 | Python | 42
#
# [ページ 42] https://github.com/orgs/google/repositories?page=42&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ process-tree | C++ | 3
#     ✓ hashtable-benchmarks | Jupyter Notebook | 111
#     ✓ json5format | Rust | 111
#     ✓ gemmlowp | C++ | 1.8k
#     ✓ play-licensing | Java | 118
#     ✓ net_http | C++ | 25
#     ✓ objax | Python | 775
#     ✓ safeopen | Go | 105
#     ✓ todo-tracks | Go | 185
#     ✓ alertmanager-irc-relay | Go | 58
#     ✓ crossmodal-3600 | HTML | 9
#     ✓ piex | C++ | 52
#     ✓ pkcs11test | C++ | 81
#     ✓ ceviche-challenges | Python | 114
#     ✓ flutter.plugins | Dart | 117
#     ✓ DOM-Tutorials | HTML | 16
#     ✓ memutil | Python | 3
#     ✓ dsg | HTML | 2
#     ✓ zoekt | 不明 | 1.7k
#     ✓ android-lint-performance-probe | Java | 157
#     ✓ break-a-scene | Python | 525
#     ✓ kinda-tidy | Python | 7
#     ✓ asml | 不明 | 5
#     ✓ impl_trait_utils | Rust | 8
#     ✓ fhir-dbt-utils | Shell | 14
#     ✓ project-eager | Jupyter Notebook | 21
#     ✓ style-aligned | Python | 1.3k
#     ✓ gce-rescue | 不明 | 14
#     ✓ maldoca | C++ | 66
#     ✓ microscopeimagequality | Python | 91
#
# [ページ 43] https://github.com/orgs/google/repositories?page=43&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ github-owners-bot | JavaScript | 50
#     ✓ valid-avatar-library | ShaderLab | 51
#     ✓ sgtm-ga4-to-bigquery | Smarty | 27
#     ✓ paco | Objective-C | 332
#     ✓ ghost-userspace | C | 236
#     ✓ waze-ccp-gcp | Python | 11
#     ✓ hadoop-migration-assessment-tools | Java | 9
#     ✓ outrigger | JavaScript | 4
#     ✓ skywater-pdk-libs-sky130_fd_io | Verilog | 11
#     ✓ bamboo-soy | Java | 48
#     ✓ web-serial-polyfill | TypeScript | 137
#     ✓ typograms | JavaScript | 1.3k
#     ✓ network-opt | C++ | 151
#     ✓ nccl-fastsocket | C++ | 122
#     ✓ cbortree | Java | 25
#     ✓ apdu | Kotlin | 8
#     ✓ ic-modeling-python | Python | 1
#     ✓ ads-account-structure-script | JavaScript | 27
#     ✓ deshell | 不明 | 4
#     ✓ ga4-gtm-migration | JavaScript | 119
#     ✓ libtracecmd-rs | Rust | 25
#     ✓ EtwToPprof | C# | 12
#     ✓ basis_universal | C++ | 10
#     ✓ sqlcommenter-laravel-php | PHP | 7
#     ✓ libtrusttoken | C++ | 15
#     ✓ go-pkcs11 | Go | 20
#     ✓ github-release-retry | Python | 15
#     ✓ java-photoslibrary | Java | 113
#     ✓ vertex-ai-nas | Python | 30
#     ✓ storybench | Python | 51
#
# ...
#     ✓ nips_assignments | C++ | 14
#     ✓ sparrowhawk | Shell | 212
#     ✓ zooshi | C++ | 291
#     ✓ http_prefetching | JavaScript | 8
#     ✓ kv-s3105c | C | 6
#     ✓ fastboot-mobile | Kotlin | 81
#     ✓ amss | R | 50
#     ✓ search-samples | Java | 549
#     ✓ abstreet | Rust | 36
#     ✓ dl_bounds | Python | 17
#     ✓ chrome-tabber | JavaScript | 14
#     ✓ beacon-platform | 不明 | 391
#     ✓ dcm_bulk_onboarding | JavaScript | 7
#     ✓ fast-simple-lcsk | C++ | 21
#     ✓ dcm-video-uploader | Python | 9
#     ✓ TouchTime | Java | 39
#     ✓ uniflow-polymer | HTML | 165
#     ✓ rally | Java | 38
#     ✓ teknowledge | Python | 30
#     ✓ clerk | C++ | 38
#     ✓ ahdlc | C | 14
#     ✓ aperture_supervision | Python | 33
#     ✓ YetAnotherChatApp | Java | 9
#     ✓ grittibanzli | C++ | 27
#     ✓ ds-trix-addon | JavaScript | 16
#
# [ページ 82] https://github.com/orgs/google/repositories?page=82&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ hat-backup | Rust | 252
#     ✓ angular-sticky-element | TypeScript | 22
#     ✓ vae-seq | Python | 177
#     ✓ cloud-cup | JavaScript | 23
#     ✓ cloud-cup-android | Java | 51
#     ✓ fest | 不明 | 10
#     ✓ decoupled_gaussian_process | Python | 24
#     ✓ safevarargs | 不明 | 7
#     ✓ opentest | 不明 | 3
#     ✓ encrypted-bigquery-client | Python | 175
#     ✓ rbe-integration-test | Python | 6
#     ✓ chained-promise | TypeScript | 53
#     ✓ synergyfinderengineered | R | 8
#     ✓ amp-client-id-library | JavaScript | 11
#     ✓ go-trace | Go | 31
#     ✓ hell0world-curriculum | HTML | 7
#     ✓ intelligent_annotation_dialogs | Jupyter Notebook | 29
#     ✓ cornerstoneMath | JavaScript | 7
#     ✓ burst-denoising | Python | 247
#     ✓ generativemloncloud | Python | 58
#     ✓ aiyprojects-deeplearn-tensorflow | TypeScript | 39
#     ✓ tensorflow-tools | JavaScript | 17
#     ✓ hugeml | 不明 | 6
#     ✓ coq-bpf | Coq | 19
#     ✓ pinotify | Java | 6
#     ✓ CallBuilder | Java | 105
#     ✓ catnip | Python | 26
#     ✓ yaricv32 | Verilog | 11
#     ✓ unigem-objective-c | Objective-C | 25
#     ✓ speech_style_transfer | HTML | 4
#
# [ページ 83] https://github.com/orgs/google/repositories?page=83&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ perf_api.dart | Dart | 9
#     ✓ golden | Go | 54
#     ✓ latency-benchmark | C | 446
#     ✓ joint_vae | OpenEdge ABL | 36
#     ✓ stumblybot | Python | 25
#     ✓ mt | C++ | 52
#     ✓ cornerstoneWebImageLoader | JavaScript | 5
#     ✓ streamy-dart | Dart | 61
#     ✓ dicomParser | JavaScript | 7
#     ✓ vulkan-cpp-library | C++ | 250
#     ✓ bbcpu | Verilog | 16
#     ✓ dev-on-chromeos-gce-setup | Shell | 7
#     ✓ pbvi | Python | 8
#     ✓ capture-thread | C++ | 100
#     ✓ pblog | C | 29
#     ✓ text2text | Python | 55
#     ✓ ce-open-data-set | 不明 | 8
#     ✓ voice-iot-maker-demo | JavaScript | 69
#     ✓ terminal-app-function-keys | Python | 89
#     ✓ FakeMaker | JavaScript | 22
#     ✓ genomics-protos | Python | 13
#     ✓ clicktrackers-panel | Python | 7
#     ✓ yara-procdump-python | C | 11
#     ✓ streaming_hdp | Go | 4
#     ✓ coursebuilder-android-container-module | Python | 23
#     ✓ sync3k-server | Scala | 21
#     ✓ tern-closure | JavaScript | 33
#     ✓ helm-broker | Go | 33
#     ✓ ndash | C++ | 40
#     ✓ VRD | Python | 6
#
# [ページ 84] https://github.com/orgs/google/repositories?page=84&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ sync3k-client | TypeScript | 19
#     ✓ acme | Go | 382
#     ✓ dart-sync-webdriver | Dart | 22
#     ✓ dart-sync-socket | Dart | 25
#     ✓ Legilimency | Python | 114
#     ✓ mipsqa | Python | 26
#     ✓ devicehub | Java | 11
#     ✓ gtd-txt | Shell | 21
#     ✓ bitutils | Python | 16
#     ✓ sonic-midi | Ruby | 17
#     ✓ gumbel_sinkhorn | Python | 76
#     ✓ arc-xcode-test-engine | PHP | 35
#     ✓ energystrategies | TypeScript | 15
#     ✓ marmot | Go | 189
#     ✓ clojure-turtle | Clojure | 428
#     ✓ dev-on-chromeos-che | 不明 | 5
#     ✓ dev-on-chromeos-openvpn | Shell | 12
#     ✓ keytransparency-java | Java | 6
#     ✓ bocado | Python | 9
#     ✓ anvil-build | Python | 58
#     ✓ river | 不明 | 4
#     ✓ trix-auto-complete | JavaScript | 17
#     ✓ MAB | R | 38
#     ✓ idris-protobuf | Idris | 32
#     ✓ energysimulation | Jupyter Notebook | 72
#     ✓ pyrios | Go | 61
#     ✓ thread-weaver | Java | 309
#     ✓ cwd_jmp | Shell | 8
#     ✓ kratu | JavaScript | 283
#     ✓ codeu_coding_assessment_b_2017 | Java | 9
#
# [ページ 85] https://github.com/orgs/google/repositories?page=85&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ coverage | Emacs Lisp | 28
#     ✓ ts-gulp | 不明 | 2
#     ✓ git-annex-external-gcs | 不明 | 4
#     ✓ makerspace-emonth | KiCad Layout | 8
#     ✓ paper-gui | HTML | 51
#     ✓ testrunner-rosemary | Java | 3
#     ✓ spline | Java | 28
#     ✓ creatism | HTML | 29
#     ✓ mockable_filesystem.dart | Dart | 12
#     ✓ okay | Go | 22
#     ✓ metaserver | Go | 10
#     ✓ microdhcpd | Go | 15
#     ✓ pubkeystore | Go | 23
#     ✓ unimorph | HTML | 20
#     ✓ GL-Shader-Validator | Python | 40
#     ✓ light-my-piano | Python | 89
#     ✓ grr_go_client | Go | 5
#     ✓ fury | Go | 35
#     ✓ grr_go_api_client | Go | 5
#     ✓ rttcp | Python | 33
#     ✓ functions-demo | JavaScript | 6
#     ✓ packet-queue | Python | 31
#     ✓ easybundler | Java | 54
#     ✓ chkstream | Python | 18
#     ✓ glmmplus | R | 12
#     ✓ codeu_coding_assessment_2017 | Java | 10
#     ✓ address-geocoder-js | HTML | 11
#     ✓ classp | Bison | 169
#     ✓ xmpmeta | C++ | 19
#     ✓ depth_fusion | C++ | 18
#
# [ページ 86] https://github.com/orgs/google/repositories?page=86&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ amp-pwa-demo | JavaScript | 113
#     ✓ Zhi | Python | 28
#     ✓ agata | JavaScript | 14
#     ✓ prerender-test | JavaScript | 15
#     ✓ audit-normalmap | C | 15
#     ✓ varstruct | C++ | 18
#     ✓ emre | C++ | 13
#     ✓ simple-reinforcement-learning | Python | 58
#     ✓ homebrew-google-authenticator | Ruby | 29
#     ✓ request-test | Python | 6
#     ✓ blockly-repo | 不明 | 10
#     ✓ pindrop | C++ | 142
#     ✓ goldfinch | 不明 | 64
#     ✓ scene_lab | C++ | 57
#     ✓ corgi | C++ | 251
#     ✓ dropzone-polyfill | HTML | 5
#     ✓ ot-crdt-papers | JavaScript | 249
#     ✓ windowtester | Java | 19
#     ✓ fpc | C | 29
#     ✓ fchan-go | Go | 311
#     ✓ xdelta3-decoder-js | C | 13
#     ✓ appengine-phabricator | Shell | 19
#     ✓ cpp-frp | C++ | 69
#     ✓ yang_vocoder | MATLAB | 91
#     ✓ keystone | Elm | 31
#     ✓ adapt-googleanalytics | JavaScript | 8
#     ✓ deepboost | C++ | 154
#     ✓ mcic-coco | 不明 | 24
#     ✓ readahead | Go | 136
#     ✓ source_transformer.dart | Dart | 9
#
# [ページ 87] https://github.com/orgs/google/repositories?page=87&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ mcafp | Python | 38
#     ✓ gtm-oauth | Objective-C | 24
#     ✓ morphie | C++ | 23
#     ✓ libgep | C++ | 55
#     ✓ smilesparser | Python | 13
#     ✓ built_json.dart | 不明 | 19
#     ✓ conferenceDB | HTML | 9
#     ✓ indexable-pwa-samples | JavaScript | 56
#     ✓ enum_class.dart | 不明 | 15
#     ✓ sass_generator | 不明 | 4
#     ✓ vpn-reverse-tether | C | 190
#     ✓ protocall | Python | 13
#     ✓ transliteration | 不明 | 56
#     ✓ power-traces | Protocol Buffer | 8
#     ✓ indexed-db-as-promised | JavaScript | 26
#     ✓ gotrace | 不明 | 21
#     ✓ cameraraw | Go | 26
#     ✓ everythingisconnected | JavaScript | 19
#     ✓ libkml | C++ | 97
#     ✓ geovelo | JavaScript | 44
#     ✓ gfw-toolkit | Python | 29
#     ✓ googleapps-message-recall | Python | 16
#     ✓ macops-MOMenu | Objective-C | 47
#     ✓ dart2java | Java | 61
#     ✓ param_runner | Shell | 4
#     ✓ gde-speakersbureau | JavaScript | 7
#     ✓ AppUpdateTrackerLib | Java | 7
#     ✓ rustcxx | Rust | 509
#     ✓ dualhttp | JavaScript | 22
#     ✓ go-webdav | Go | 70
#
# [ページ 88] https://github.com/orgs/google/repositories?page=88&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ dorusu-js | JavaScript | 40
#     ✓ identity-toolkit-go-client | Go | 57
#     ✓ dynamex-proto | Protocol Buffer | 7
#     ✓ auto-common | 不明 | 5
#     ✓ auto-service | 不明 | 5
#     ✓ auto-factory | 不明 | 5
#     ✓ prudaq | Eagle | 123
#     ✓ realtime-help | Python | 20
#     ✓ pepper.js | JavaScript | 324
#     ✓ instant-hangouts | JavaScript | 184
#     ✓ LiquidFunPaint | Java | 166
#     ✓ easy-gwt-mock | Java | 13
#     ✓ gofountain | Go | 110
#     ✓ VoltAir | C++ | 317
#     ✓ bzip2-rpc | C | 14
#     ✓ gipfeli | C++ | 117
#     ✓ go-circuits | Go | 15
#     ✓ rpki-mgmt | Puppet | 6
#     ✓ simplecfg | Java | 11
#     ✓ maketrace | C++ | 19
#     ✓ Chrome.Docs | JavaScript | 27
#     ✓ bluesky-watchface | C | 11
#     ✓ slowfs | Go | 58
#     ✓ arc-jazzy-linter | PHP | 18
#     ✓ merge_pyi | Python | 15
#     ✓ drone-firebase | Go | 14
#     ✓ cncmicroscope-cad | OpenSCAD | 15
#     ✓ access-bridge-explorer | C# | 126
#     ✓ gitwf | 不明 | 4
#     ✓ arc-proselint | PHP | 17
#
# [ページ 89] https://github.com/orgs/google/repositories?page=89&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ channel-id-enclave | 不明 | 33
#     ✓ generator-goro | JavaScript | 24
#     ✓ xpaf | C++ | 153
#     ✓ google-empty-test-module | 不明 | 3
#     ✓ cloud-reporting | Java | 8
#     ✓ reagera | Java | 13
#     ✓ py-decorators-tutorial | Jupyter Notebook | 31
#     ✓ identity-toolkit-node-client | JavaScript | 30
#     ✓ GOS-conventions | Shell | 8
#     ✓ identity-toolkit-java-client | Java | 37
#     ✓ jalic | C | 11
#     ✓ arc-regex-line-length-linter | PHP | 8
#     ✓ identity-toolkit-ruby-client | Ruby | 10
#     ✓ file-system-stress-testing | C | 104
#     ✓ linux-sensor | C | 32
#     ✓ multibox | 不明 | 307
#     ✓ offline-content-packager | 不明 | 35
#     ✓ crush-tools | Shell | 150
#     ✓ flutter-data | Dart | 11
#     ✓ resolver-library | Python | 7
#     ✓ hops | C++ | 11
#     ✓ kythe-cloud9 | JavaScript | 7
#     ✓ physical-web-core | 不明 | 3
#     ✓ flooefi | 不明 | 10
#     ✓ serialization.dart | Dart | 32
#     ✓ templatekit | Objective-C | 19
#     ✓ metrosvg | C++ | 13
#     ✓ paramgmt | Python | 85
#     ✓ pienoon | C++ | 438
#     ✓ translation-cards | Java | 17
#
# [ページ 90] https://github.com/orgs/google/repositories?page=90&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ topdown-btg-preordering | C++ | 16
#     ✓ openpgp-interop | 不明 | 8
#     ✓ appengine-codiad | JavaScript | 39
#     ✓ godata | Go | 26
#     ✓ opentest4j | Java | 5
#     ✓ identity-toolkit-php-client | PHP | 37
#     ✓ google-maven-parents | 不明 | 6
#     ✓ identity-toolkit-python-client | Python | 32
#     ✓ Refaster | Java | 54
#     ✓ strabo | Elixir | 60
#     ✓ http2preload | Go | 20
#     ✓ checkers_classic | Python | 7
#     ✓ node-nest | JavaScript | 4
#     ✓ intellij-cmdline-vcs-plugin | Java | 4
#     ✓ docopt-scripts | Go | 6
#     ✓ xpra-upstart | 不明 | 3
#     ✓ steamkeysactivator | AppleScript | 29
#     ✓ homebrew-xpra | Ruby | 9
#     ✓ shipshape-demo | Python | 4
#     ✓ hashing-demo | C++ | 29
#     ✓ autopiper | C++ | 48
#     ✓ inception | 不明 | 877
#     ✓ clang-lens | Haskell | 20
#     ✓ crisis-info-hub | JavaScript | 35
#     ✓ dart-immutables | Dart | 6
#     ✓ streamhtmlparser | C | 17
#     ✓ pods-helper | Objective-C | 5
#     ✓ cluster-insight | Python | 99
#     ✓ freebase-wikidata-converter | PHP | 63
#     ✓ snappy-start | C | 450
#
# [ページ 91] https://github.com/orgs/google/repositories?page=91&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ capsicum-man-pages | Groff | 10
#     ✓ rust-multihash | Rust | 62
#     ✓ organ-donor-app | 不明 | 3
#     ✓ trace-viewer | 不明 | 491
#     ✓ rowhammer-test | C++ | 984
#     ✓ ferret | Java | 8
#     ✓ module-server | JavaScript | 565
#     ✓ autoparse | Ruby | 146
#     ✓ android-studio-check | Java | 14
#     ✓ chromeos-filesystems | JavaScript | 125
#     ✓ gojiraw | Go | 16
#     ✓ terminal-py | Python | 7
#     ✓ lmctfy | C++ | 3.4k
#     ✓ dart-shapeshift | Dart | 13
#     ✓ calenviroscreen | R | 8
#     ✓ cncmicroscope-code | C++ | 24
#     ✓ o3dtoydefense | JavaScript | 8
#     ✓ epr | JavaScript | 16
#     ✓ codename-mvsv | JavaScript | 9
#     ✓ io-captions-gadget | Python | 5
#     ✓ ytstatistics-demo | Java | 5
#     ✓ sensei | C++ | 55
#     ✓ comid | Dart | 15
#     ✓ service_worker.dart | Dart | 9
#     ✓ google-visualization-issues | 不明 | 286
#     ✓ dart-doc_coverage | Dart | 7
#     ✓ voter-info-tool | JavaScript | 7
#     ✓ chrome-language-immersion | JavaScript | 46
#     ✓ coursebuilder_xblock_module | Python | 17
#     ✓ py-html-contextual-escaping | Python | 4
#
# [ページ 92] https://github.com/orgs/google/repositories?page=92&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ json-sans-eval | HTML | 7
#     ✓ mysql-tools | Python | 212
#     ✓ refr | C++ | 28
#     ✓ coursebuilder-hello-world-module | Python | 8
#     ✓ dart-emacs-plugin-unsupported | Emacs Lisp | 12
#     ✓ older-mirrored-patches | 不明 | 4
#     ✓ objectfilter | Python | 4
#     ✓ retrofit | Java | 43
#     ✓ nfc-smart-tag | Java | 12
#     ✓ irrduino | Processing | 51
#     ✓ reportlatency | Perl | 6
#     ✓ gmailsnooze | JavaScript | 16
#     ✓ deliberate | 不明 | 4
#     ✓ network-visualizer-x | 不明 | 5
#     ✓ reboot-somalia | 不明 | 3
#     ✓ citizen-x | 不明 | 5
#     ✓ pytypedecl | Python | 66
#     ✓ rysim | Erlang | 7
#     ✓ jsontoken-tmp | 不明 | 3
#     ✓ go-shlex | 不明 | 5
#     ✓ zarathustra | Java | 14
#     ✓ pull-request-mailer | Haskell | 45
#     ✓ elfling | C++ | 25
#     ✓ vim-ft-vroom | Vim Script | 12
#     ✓ picview-for-android | Java | 51
#     ✓ picasa-app-demo | Java | 10
#     ✓ web-starter-kit-extras | 不明 | 71
#     ✓ simple-pedometer | Java | 77
#     ✓ sensor-data-collection-library | Java | 46
#     ✓ ashier | Python | 29
#
# [ページ 93] https://github.com/orgs/google/repositories?page=93&tab=repositories
#   ステータスコード: 200
#   ✓ 30個のリポジトリ要素を発見
#     ✓ coursebuilder-lti-module | Python | 16
#     ✓ episodes.dart | Dart | 14
#     ✓ polymer-dart-log-controller | Dart | 8
#     ✓ ebola-tools | Python | 15
#     ✓ pubsubhubbub | 不明 | 6
#     ✓ dart-tagtree | Dart | 78
#     ✓ turing-doodle | JavaScript | 170
#     ✓ linear-book-scanner | Python | 81
#     ✓ java-thread-sanitizer | Java | 76
#     ✓ gin | 不明 | 5
#     ✓ go-glicko2 | 不明 | 5
#     ✓ rct-automation | C++ | 23
#     ✓ Idris-dev | Haskell | 9
#     ✓ forcefield | Gosu | 48
#     ✓ dart-gif-encoder | Dart | 28
#     ✓ glassbox | R | 22
#     ✓ coursebuilder-learning-analytics | 不明 | 5
#     ✓ NLSdata | R | 8
#     ✓ jenkins-flaky-test-report | 不明 | 5
#     ✓ build-debian-cloud | Python | 35
#     ✓ dart-collab | Dart | 47
#     ✓ wheelbarrow | Python | 11
#     ✓ photo-sphere | 不明 | 4
#     ✓ oss-bench | 不明 | 6
#     ✓ heartbleed-burp-extension | Java | 13
#     ✓ lab_device_proxy | Python | 39
#     ✓ gdal-autotest2 | 不明 | 4
#     ✓ patchfield | Java | 277
#     ✓ googleapps-password-generator | 不明 | 27
#     ✓ YouCompleteSubl | 不明 | 2
#
# [ページ 94] https://github.com/orgs/google/repositories?page=94&tab=repositories
#   ステータスコード: 200
#   ✓ 22個のリポジトリ要素を発見
#     ✓ favcolor-findidp | 不明 | 5
#     ✓ appengine_xblock_runtime | Python | 19
#     ✓ memcache-collections | Python | 66
#     ✓ course-builder | 不明 | 5
#     ✓ favcolor-android | Java | 40
#     ✓ systemjs | JavaScript | 64
#     ✓ favcolor-ios | 不明 | 5
#     ✓ pixelcycle-sample-app | Dart | 10
#     ✓ container-rfc | 不明 | 11
#     ✓ gae-channel-api.dart | Dart | 10
#     ✓ ChannelPlate | JavaScript | 23
#     ✓ testRunner | JavaScript | 10
#     ✓ devtoolsExtended | JavaScript | 73
#     ✓ self-hosted-rss-to-email | Go | 29
#     ✓ zimu | C | 6
#     ✓ tsviewdb | JavaScript | 125
#     ✓ beta-binomial-fitting | 不明 | 6
#     ✓ wiberg-minimization | 不明 | 17
#     ✓ crx2app | JavaScript | 22
#     ✓ concatenate.js | JavaScript | 92
#     ✓ firmata.py | Python | 21
#     ✓ sirius | 不明 | 8
#
# ============================================================
# 取得したリポジトリ数: 2812
# ============================================================
# 1. bazel-common
#    言語: Starlark
#    スター: 91
#
# 2. XNNPACK
#    言語: C
#    スター: 2.2k
#
# 3. osv-scalibr
#    言語: Go
#    スター: 536
#
# 4. open-dice
#    言語: C++
#    スター: 26
#
# 5. heir
#    言語: C++
#    スター: 609
#
# 6. dive
#    言語: C++
#    スター: 17
#
# 7. chromium-policy-vulnfeed
#    言語: Go
#    スター: 7
#
# 8. site-kit-wp
#    言語: JavaScript
#    スター: 1.3k
#
# 9. toucan
#    言語: C++
#    スター: 48
#
# 10. xls
#    言語: C++
#    スター: 1.4k
#
# 11. nomulus
#    言語: Java
#    スター: 1.8k
#
# 12. oss-fuzz
#    言語: Shell
#    スター: 12k
#
# 13. docsy
#    言語: JavaScript
#    スター: 2.9k
#
# 14. tunix
#    言語: Python
#    スター: 1.9k
#
# 15. gemma.cpp
#    言語: C++
#    スター: 6.6k
#
# 16. osv-scanner
#    言語: Go
#    スター: 8.1k
#
# 17. cassowary.dart
#    言語: Dart
#    スター: 44
#
# 18. nsjail
#    言語: C++
#    スター: 3.6k
#
# 19. zerocopy
#    言語: Rust
#    スター: 2.1k
#
# 20. flatbuffers
#    言語: C++
#    スター: 25k

# %%
# SQLiteデータベースに保存
import sqlite3

print("データベースへの保存を開始します")

# データベースに接続
conn = sqlite3.connect('repository.db')
cursor = conn.cursor()

# データを挿入
insert_count = 0
for repo in repositories:
    try:
        cursor.execute('''
            INSERT INTO rep (name, language, star)
            VALUES (?, ?, ?)
        ''', (repo['リポジトリ名'], repo['主要な言語'], repo['スター数']))
        insert_count += 1
    except sqlite3.Error as e:
        print(f"挿入エラー: {repo['リポジトリ名']} - {e}")

conn.commit()
print(f"✓ {insert_count}件のデータを挿入しました")

# 確認
cursor.execute('SELECT COUNT(*) FROM rep')
total_count = cursor.fetchone()[0]
print(f"✓ データベース内の総レコード数: {total_count}件")

conn.close()
print("✓ データベース接続を閉じました")
# Out:
# データベースへの保存を開始します
# ✓ 2812件のデータを挿入しました
# ✓ データベース内の総レコード数: 2812件
# ✓ データベース接続を閉じました

# %%
path = ''
db_name = 'repository.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL(RDBを操作するための言語)カーソルオブジェクトを取得
    cur = conn.cursor()

    # データを参照するSQL
    # SELECT * FROM テーブル名;
    # *の部分は全てのカラムを意味する
    sql = 'SELECT * FROM rep;'

    # SQLの実行
    cur.execute(sql)

    # 変更を保存する
    # conn.commit()

except sqlite3.Error as e:
    print('エラーが発生しました:', e)

else:
    for row in cur:
        # 行データ(row)はタプルなので、アンパックして列データを取得
        language, name, star = row
        print(name, language, star)

finally:
    # DBへの接続を閉じる
    conn.close()
# Out:
# Starlark bazel-common 91
# C XNNPACK 2.2k
# Go osv-scalibr 536
# C++ open-dice 26
# C++ heir 609
# C++ dive 17
# Go chromium-policy-vulnfeed 7
# JavaScript site-kit-wp 1.3k
# C++ toucan 48
# C++ xls 1.4k
# Java nomulus 1.8k
# Shell oss-fuzz 12k
# JavaScript docsy 2.9k
# Python tunix 1.9k
# C++ gemma.cpp 6.6k
# Go osv-scanner 8.1k
# Dart cassowary.dart 44
# C++ nsjail 3.6k
# Rust zerocopy 2.1k
# C++ flatbuffers 25k
# Java dwh-migration-tools 54
# C++ android-cuttlefish 571
# C++ ink 49
# C++ or-tools 13k
# Jsonnet earthengine-catalog 121
# Java error-prone 7.1k
# C++ angle 3.8k
# C++ perfetto 5k
# Python oss-fuzz-vulns 166
# C++ skia 10k
# Go skia-buildbot 158
# Java device-infra 58
# Python meridian 1.2k
# Rust gn-language-server 18
# Rust matr 9
# C++ dawn 778
# Python langfun 875
# Go osv-scanner-v1 2
# HTML adk-docs 974
# C++ quiche 801
# Kotlin private-compute-libraries 34
# Java gson 24k
# C kafel 340
# Python adk-python 16k
# Java mug 444
# C++ biva 6
# Kotlin ground-android 272
# Go gvisor 17k
# TypeScript budoux-extension 16
# C++ tabuli 35
# C++ filament 19k
# Go adk-go 4.6k
# Python Xee 320
# TypeScript safevalues 137
# Python init2winit 79
# Kotlin jetpack-camera-app 276
# Python orbax 455
# C++ eclipsa-audio-plugin 56
# TypeScript adk-js 99
# C++ crubit 924
# Java cel-java 227
# Starlark cel-spec 3.5k
# C++ nearby 887
# Rust crosvm 1.1k
# Python grain 602
# TypeScript ground-platform 227
# JavaScript earthengine-api 3.1k
# JavaScript closure-compiler 7.6k
# Python dotprompt 328
# Kotlin kotlin-fhirpath 6
# C++ bloaty 5.3k
# Python civics_cdf_validator 34
# C++ netkat 27
# C++ koladata 27
# Kotlin virtual-printer 2
# Python garf 11
# C++ benchmark 9.9k
# Python digitalbuildings 424
# Shell oracle-toolkit 65
# C++ fuzztest 924
# HTML fonts 19k
# C++ gfxstream 21
# Python clusterfuzz 5.5k
# TypeScript xrblocks 153
# C++ cel-cpp 205
# Java closure-templates 671
# Java TestParameterInjector 415
# Svelte sec-gemini 107
# Rust secure-aggregation 5
# C security-research 4.3k
# Rust automotive-design-compose 167
# Java dagger 18k
# C# embardiment 10
# C++ llvm-propeller 464
# Go syzkaller 5.9k
# Java adk-java 964
# C++ ecclesia-machine-management 15
# JavaScript zx 45k
# C++ s2geometry 2.6k
# Jupyter Notebook earthengine-community 743
# Python timesketch 3.2k
# C++ yggdrasil-decision-forests 621
# Python testrun 42
# Dart dart-neats 503
# C++ mozc 2.8k
# C++ highway 5.1k
# Go go-querystring 2.1k
# TypeScript brotli 14k
# Rust googletest-rust 393
# Dart built_value.dart 883
# Jupyter Notebook brax 2.9k
# Go seesaw 5.7k
# C++ oboe 4k
# C++ boringssl 2.1k
# Python torchax 130
# Go go-containerregistry 3.6k
# Go go-units 7
# Python osv.dev 2.4k
# Java j2cl 1.3k
# Python ml-metrics 19
# Go pullsheet 88
# Python nsscache 150
# Python adk-samples 6.4k
# C++ tcmalloc 5k
# Python aqt 337
# Rust pdl 66
# Python mcp-security 404
# Go oss-rebuild 669
# Python atheris 1.5k
# Python adk-python-community 95
# Dart json_serializable.dart 1.6k
# Kotlin ksp 3.3k
# Python qwix 63
# Go jsonschema-go 139
# Go gops 7k
# Rust tarpc 3.6k
# Go dranet 146
# Go go-attestation 404
# Python filonov 10
# C libnss-cache 61
# Rust assertor 144
# Jupyter Notebook flax 6.9k
# LLVM clspv 693
# Python langextract 17k
# Rust pack 202
# C++ gurl 0
# C++ shell-encryption 124
# Go certificate-transparency-go 1.1k
# Dart source_helper.dart 16
# Java conscrypt 1.4k
# C++ libphonenumber 18k
# Java copybara 2.5k
# C++ sentencepiece 11k
# C++ snappy 6.5k
# Go trillian-examples 173
# Kotlin android-security-lints 153
# Python secops-wrapper 44
# TypeScript workflow-graph 149
# Kotlin android-fhir 571
# C++ silifuzz 412
# C++ tensorstore 1.5k
# TypeScript peoplemath 128
# Go fscrypt 982
# Go trillian 3.7k
# Go go-github 11k
# Go gke-policy-automation 525
# Java merchant-api-samples 10
# Go go-cloud 9.8k
# Go aoss-verifier 25
# Go go-jsonnet 1.8k
# Go certtostore 96
# TypeScript neuroglancer 1.2k
# C minijail 342
# Python osv-scanner-action 47
# Python jax-datetime 2
# C glome 63
# C++ gutil 11
# C++ fleetbench 134
# HTML across 21
# Python scaaml 175
# C++ fhir 904
# Kotlin horologist 657
# C++ nccl-plugin-gpudirect-tcpxo 6
# C++ tsl 101
# Go gnostic-models 20
# Go go-sev-guest 66
# Java fhir-gateway 90
# Kotlin kotlin 153
# 不明 android-beat 2
# Python bumble 426
# C++ gwpsan 327
# Go nftables 1.3k
# Rust wasefire 127
# TypeScript clasp 5.3k
# Java guava 51k
# Go go-tdx-guest 79
# Dart googleapis.dart 408
# Python openhtf 613
# 不明 github_workflows_playground 8
# TypeScript adk-web 673
# Go gce-tcb-verifier 22
# Shell github-team 2
# Python pyglove 699
# C++ shaderc 2.1k
# Jupyter Notebook fhir-data-pipes 204
# Go cel-go 2.8k
# C++ arolla 23
# Go inverting-proxy 262
# C# ChromeBrowserEnterprise 57
# TypeScript travel-impact-model-website 5
# Python learned_optimization 788
# Go rpmpack 128
# C++ cctz 631
# Python weather-tools 241
# TypeScript schema-dts 1.1k
# C++ foteli 5
# Dart protobuf.dart 558
# Python sedpack 28
# Rust mdbook-i18n-helpers 194
# Go deps.dev 354
# TypeScript tsec 141
# 不明 github-sandbox 16
# TypeScript dotguides 21
# Rust aarch64-esr-decoder 99
# Python torq 2
# Smarty osdfir-infrastructure 171
# Python github_nonpublic_api 43
# C libhoth 17
# Python oss-fuzz-gen 1.3k
# Java auto 11k
# Python xctestrunner 153
# Java escapevelocity 39
# TypeScript postcss-rename 162
# Python praxis 190
# 不明 transit 852
# C++ riegeli 465
# C++ swiftshader 2.4k
# Rust osdemo 8
# Java j2objc 6k
# Java turbine 82
# Go differential-privacy 3.3k
# Java caliper 819
# 不明 aidl-language 23
# 不明 selinux-policy-languages 14
# 不明 pdl-language 26
# Rust comprehensive-rust 32k
# Dart webcrypto.dart 97
# Python budoux 1.5k
# Python pytype 5k
# Python paxml 540
# Go renameio 666
# Python seqio 589
# Objective-C google-toolbox-for-mac 1.2k
# Objective-C gtm-session-fetcher 265
# Rust alioth 307
# TypeScript iwa-vscode-extension 3
# Python mobly 716
# TypeScript project-voice 49
# Python duet 24
# Rust cro3 49
# TypeScript arb-editor 56
# TypeScript codeql-action 0
# Python dfindexeddb 38
# Kotlin sound-checker 22
# TypeScript traceviz 4
# Python etils 244
# Jupyter Notebook labs-prototypes 85
# Dart vector_math.dart 341
# Go pprof 8.9k
# 不明 rust-crate-audits 255
# Rust aarch64-rt 17
# TypeScript aside 392
# Go privacy-sandbox-aggregation-service 28
# Rust rbrotli-enc 13
# TypeScript ads-api-report-fetcher 53
# Java guice 13k
# Java mobly-bundled-snippets 54
# Python metrax 47
# Python magika 9.8k
# Python symphony-gcp 1
# Python cameratrapai 386
# Python ml-compiler-opt 737
# M4 google-cloud-datastore-quadruple 2
# HTML styleguide 39k
# C++ array_record 123
# Python mobly-android-screen-recorder 5
# HTML certificate-transparency-community-site 132
# Java tsunami-security-scanner-plugins 942
# Java tsunami-security-scanner 8.5k
# Go keep-sorted 316
# HTML docsy-example 537
# C++ perf_data_converter 331
# C android-emulator-hypervisor-driver 840
# Python ads_oneshop 19
# Objective-C EarlGrey 5.7k
# C++ zetasql 2.4k
# 不明 myvibe 4
# Jupyter Notebook business_intelligence_group 14
# Python mobly-bluetooth-ref-validation 5
# C++ googletest 38k
# Go cloud-android-orchestration 58
# Java compile-testing 715
# Python fhir-py 94
# TypeScript product_video_ads 61
# Java xplat 18
# Go go-tpm 616
# Java guava-beta-checker 91
# C google-authenticator-libpam 1.9k
# Python spatial-media 2k
# Java jimfs 2.5k
# Java truth 2.8k
# C++ longfellow-zk 983
# C++ kernel-research 48
# Java bindiff 2.8k
# Go shifter 45
# TypeScript cddlconv 11
# Rust coset 38
# Go sbom-conformance 2
# Go starlark-go 2.6k
# Objective-C GoogleSignIn-iOS 667
# Rust rust_icu 128
# C++ jsir 108
# Java walt 462
# Jupyter Notebook meterstick 109
# C++ cpu_features 2.6k
# C++ binexport 1.2k
# Kotlin kotlin-fhir 53
# Python saxml 146
# Jupyter Notebook ever 14
# TypeScript sso-offloading 1
# Go kf 400
# Python vizier 1.6k
# Go instrumentsToPprof 52
# C++ mozc-devices 2.7k
# Python ml_collections 998
# 不明 graph-renderer 0
# Go container-explorer 89
# Go googet 98
# Objective-C google-api-objectivec-client-for-rest 830
# Java desugar_jdk_libs 389
# Python uncertainty-baselines 1.6k
# Python bt-navi-tests 5
# Go capslock 1.1k
# C go-tpm-tools 271
# Jupyter Notebook jax-cfd 894
# C++ p4-infra 1
# Kotlin kotlin_convert 20
# Dart built_collection.dart 283
# Dart quiver-dart 1.1k
# C++ pthreadpool 22
# Dart webkit_inspection_protocol.dart 33
# JavaScript semantic-locators 58
# 不明 brotli-wheels 10
# 不明 openintent 33
# C++ re2 9.5k
# 不明 bughunters 139
# Mathematica filament-assets 1
# Python xarray-beam 158
# CSS gsocguides 475
# C++ mpact-cheriot 6
# Python glazier 1.2k
# C++ mpact-riscv 26
# Python tfp-causalimpact 135
# C fscryptctl 137
# Python capirca 839
# C++ imt 5
# C neper 318
# C++ autofdo 575
# Python ARC-GEN 33
# Go fresnel 55
# Dart dart_cli_pkg 61
# Python fiddle 364
# Java elemental2 167
# Java jsinterop-base 72
# Java jsinterop-annotations 21
# Java jsinterop-generator 82
# ABAP genie-for-sap-abap-ai-assistant-sample 26
# Rust omaha-client 6
# Rust sbat-rs 18
# Rust authenticode-rs 30
# Rust gpt-disk-rs 71
# Python hackable_diffusion 24
# Jupyter Notebook zimtohrli 172
# Dart uri.dart 80
# Go mangle 2.9k
# Dart mono_repo.dart 165
# Python python-fire 28k
# 不明 ragvis 1
# Python xarray-tensorstore 61
# Java flogger 1.5k
# C++ breakpad 2.8k
# C++ hotels-template-library 24
# Python google-ctf 4.8k
# Dart process_runner 20
# C nsync 1.2k
# C++ quic-trace 119
# Python temporian 703
# Go mtail 4k
# C++ obr 22
# Python turbinia 777
# Java google-java-format 6k
# Go addlicense 850
# Swift GoogleAppMeasurement 31
# Rust rrg 59
# Python evt-air-risk-aiaa-scitech-2026 2
# Kotlin watchface 52
# C++ double-conversion 1.2k
# Go der-ascii 248
# Java inject-common 11
# Python jaxite 88
# Python airio 21
# Go buzzer 467
# C++ jpegli 277
# Go ts-bridge 54
# Python slo-generator 546
# Python autobound 363
# Java pdsl-xray 2
# Go test-server 17
# Python sbsim 86
# Go tracey 6
# Go smbios-validation-tool 12
# Shell pmax_best_practices_dashboard 52
# Jupyter Notebook pubmed-rag 11
# C++ loudness_ebur128 3
# Python python-proto-converter 15
# Go pathways-job 15
# JavaScript humanio 14
# C++ anonymous-tokens 58
# Objective-C eDistantObject 176
# Go fleetspeak 142
# Go yamlfmt 1.6k
# Python tf-shell 9
# C++ rootcanal 30
# 不明 skcms 3
# Python deepvariant 3.6k
# Python drjax 15
# Jupyter Notebook jaxloop 18
# C++ private-join-and-compute 833
# Python gnxi 282
# Go winops 121
# Java intellij-community 12
# TypeScript wireit 6.3k
# Rust aarch64-paging 38
# Rust synopsys-dw-uart 1
# Rust command-fds 41
# Rust OpenSK 3.2k
# Python capsem 0
# C++ private-membership 49
# Python yapf 14k
# C rune 1.9k
# HTML trillian-website 12
# Python vanir 342
# Go cabbie 99
# 不明 travel-impact-model 164
# C++ sandboxed-api 1.7k
# 不明 deepsomatic 275
# Go licenseclassifier 339
# C++ distbench 54
# Kotlin ide-perf 65
# Rust native-pkcs11 64
# C++ mpact-sim 37
# HTML webview-ads 1
# Python gematria 91
# Go taxinomia 1
# 不明 opendocs 199
# Python jaxopt 1k
# YARA threat-team 54
# Jupyter Notebook generative-ai-docs 2.2k
# 不明 oss-policies-info 28
# Python cloud-forensics-utils 489
# C++ play-unreal-engine-plugin 12
# Tcl security-testbeds 52
# C++ amber 214
# Haskell proto-lens 497
# Java play-services-plugins 503
# C packetdrill 950
# Dart codemirror.dart 87
# Python emboss 82
# TypeScript playground-elements 625
# Java snippet-uiautomator 46
# HTML slowjam 252
# Go fswalker 109
# C sanitizers 12k
# Dart reflectable.dart 382
# Java private-compute-services 531
# JavaScript llm-sidebar-with-context 4
# Jupyter Notebook mediapy 440
# Python learn-oss-with-google 43
# HTML google.github.io 533
# C++ minimalloc 175
# Rust smccc 8
# 不明 s2a-proto 0
# Go s2a-go 25
# Objective-C GoogleUtilities 121
# C++ mount-zip 221
# Go dnsmasq_exporter 184
# C++ libultrahdr 263
# Swift GTMAppAuth 413
# Python ffn 339
# Python trax 8.3k
# Python mobly-wifi 7
# R CausalImpact 1.8k
# Python create-service-account 25
# 不明 wmt-mqm-human-evaluation 96
# Java polymorphicDSL 12
# Python apitools 145
# Java flink-connector-gcp 12
# Java bundletool 3.9k
# C++ rdma-unit-test 30
# Python GiftStick 142
# C++ minja 198
# Python gin-config 2.1k
# Go quahog 2
# Java sagetv 280
# Groovy protobuf-gradle-plugin 1.8k
# Python struct2tensor 34
# 不明 material-design-icons 53k
# JavaScript closure-compiler-npm 339
# Java allocation-instrumenter 487
# C++ draco 7k
# JavaScript jscin 45
# Rust kati 994
# Objective-C GoogleDataTransport 53
# Go cql 94
# Objective-C interop-ios-for-google-sdks 13
# Objective-C app-check 31
# C++ fully-homomorphic-encryption 3.6k
# TypeScript strict-csp 48
# Python jaxonnxruntime 125
# Go subcommands 784
# Java ukey2 48
# Python dataflow-ml-starter 24
# Rust async-request-dispatcher-rs 3
# JavaScript virtual-broadcast-production-assistant 17
# C honggfuzz 3.3k
# Go kctf 731
# Python gcp_scanner 341
# C++ bigwheels 101
# JavaScript web-game-samples 59
# Rust fleetspeak-rs 10
# Jupyter Notebook eng-edu 734
# Jupyter Notebook edward2 702
# C++ fuse-archive 223
# Go github-webhook-pubsub-bridge 6
# Rust safe-mmio 17
# Rust percore 8
# Go go-licenses 961
# C++ pybind11clif 70
# Rust shaderc-rs 282
# 不明 closure-net 3
# Python rax 335
# Go go-dap 133
# C++ distributed_point_functions 77
# Rust rust-scudo 59
# Rust casimir 1
# JavaScript ota-analyzer 13
# Java crumbles 5
# Dart tuple.dart 194
# Dart grinder.dart 266
# Dart webdriver.dart 141
# Dart sync_http.dart 17
# Dart flutter-mediapipe 270
# Dart dart-basics 164
# C++ genc 63
# Jupyter Notebook carfac 131
# Go kube-startup-cpu-boost 508
# C++ jni-bind 304
# Rust autocxx 2.5k
# Haskell ghc-source-gen 99
# Java tsunami-security-scanner-callback-server 18
# 不明 partner-ads-experience 4
# C++ fast-isotropic-median-filter 16
# C++ ink-stroke-modeler 104
# JavaScript cad_campaign_anomaly_detector 11
# Go pcie_lmt 7
# C++ llvm-memprof 4
# Apex soql-tool 0
# Rust pl011-uart 6
# 不明 saif-data 4
# TypeScript link-diver 69
# Go wire 14k
# Swift grpc-binary 10
# HTML kunit-docs 29
# Apex evolve-forms 175
# Python matched_markets 94
# TypeScript flow-lens 72
# 不明 distributed_graph_flow 0
# Go go-eventlog 15
# 不明 Serberus 13
# C++ node-gles 331
# TypeScript co-op-4-all 10
# Jupyter Notebook data-driven-discretization-1d 168
# Python howtodiv 8
# Python corpuscrawler 211
# Kotlin accompanist 7.8k
# Python proto-task-queue 10
# Rust arm-gic 38
# Python python-spanner-orm 40
# C multichase 146
# C++ graph-mining 712
# Lua executor.nvim 153
# Java s2-geometry-library-java 578
# Go gnostic 2.2k
# TeX cluster-data 1k
# Python speaker-id 436
# Go localtoast 114
# Go generative-ai-go 830
# TypeScript if-this-then-ad 99
# Jupyter Notebook dynamicworld 153
# C++ effcee 102
# Python facade 134
# JavaScript har2csv 46
# TypeScript reflow-list 8
# TypeScript model-viewer 7.7k
# Python esamplusplus 4
# Vue devlibrary 194
# Python shoptimizer 48
# Ruby safe-active-record 18
# Python practical-inverse-rendering-of-textured-and-translucent-appearance 113
# Jupyter Notebook deluca 124
# Python wci 36
# Python csv-to-firestore 25
# HTML tacotron 540
# Python sequence-layers 46
# JavaScript conversational-surveys 6
# Rust ippusb 4
# Python rubik 28
# C vbootrom 16
# JavaScript web-hv 46
# TypeScript safety-web 27
# Rust argh 1.9k
# Python fedjax 266
# Jsonnet jsonnet 7.4k
# Go chrome-ssh-agent 274
# Ruby hrx-ruby 12
# C smc-hello-world 1
# C smc-common 1
# Go deku 6
# Go code-review-bot 101
# Go truestreet 42
# Python python-card-framework 22
# C++ ruy 316
# C wuffs 4.7k
# Python gmail-oauth2-tools 464
# Go triage-party 521
# Go web-api-gateway 46
# JavaScript payjs 7
# Go gonids 189
# Rust flyweights 2
# Vue litmus 38
# Python gtest-parallel 454
# Python ml-edu 6
# 不明 automotive-design-compose-protos 0
# JavaScript swissgl 1.2k
# C++ rde-tester 1
# JavaScript refvnli 0
# Rust CoMMA 10
# JavaScript fsl-gaming 25
# PowerShell terraform-google-sqlserver 3
# HCL cost-attribution-solution 37
# Python lmeval 235
# TypeScript tachometer 726
# C ios-webkit-debug-proxy 6.1k
# 不明 apilark 6
# Python tcli 9
# 不明 app-resource-bundle 155
# PHP recaptcha 3.5k
# Go ent 75
# Jupyter Notebook CommonLoopUtils 358
# Go ebpf-transport-monitoring 23
# Python rago 21
# Go aukera 41
# Java open-location-code 4.3k
# Python jaxcam 13
# Python content_recommendation_using_word2vec 27
# Go safehtml 373
# Jupyter Notebook forest-data-partnership 35
# Python lightweight_mmm 1k
# Python gazoo-device 23
# Python bt-test-interfaces 14
# Python avatar 20
# Python paranoid_crypto 796
# C++ proto-splitter 1
# Go cadvisor 19k
# HTML unblocking-detail-caption 1
# Jupyter Notebook auto-arborist 13
# Python qkeras 578
# Rust pts-bot 4
# Python vroom 274
# C++ libaddressinput 606
# Java android-key-attestation 213
# TypeScript dv360-duplicator 20
# C eiffel 5
# Jupyter Notebook skyline_rl_lab 6
# Go pseudo-identity-provider 9
# Python llvm-premerge-checks 43
# Go go-configfs-tsm 8
# Python grr 5k
# Jupyter Notebook sandwiched_compression 48
# Python gemma_pytorch 5.6k
# Go go-safeweb 1.5k
# TypeScript visualblocks 1.3k
# Go codesearch 3.9k
# TypeScript webauthndemo 621
# C++ UIforETW 1.6k
# C hiba 384
# Python pyink 280
# Rust vk-layer-for-rust 14
# C liblc3 225
# Dart taqo-paco 12
# Java jse4conf 6
# C++ synthmark 55
# HTML df-conformer 31
# Java zetasketch 163
# C++ cairn 5
# Go agi 1k
# C++ lullaby 1.2k
# C++ visqol 836
# C++ glog 7.3k
# Python uvq 119
# C++ aegis_cipher 25
# Python consent-based-conversion-adjustments 25
# C containerdbg 74
# Python Stereoscopic-Video-Generation-via-Denoising-Frame-Matrix 8
# C++ iopddl 23
# Go badwolf-drivers 22
# Dart project-euphonia-app 29
# Go badwolf 984
# C++ fruit 1.9k
# Python sa360-bigquery-bootstrapper 6
# C# gemma-unity-plugin 79
# C# gemma-journey 28
# Python feabench 4
# Go hashr 126
# Go regexpand 8
# Python myelin-acorn-electron-hardware 59
# TypeScript vscode-vnc 5
# Python pica 55
# Rust strangemeadowlark 3
# Go note-maps 129
# Jupyter Notebook curie 28
# Python mobly-cros 2
# Go go-tika 253
# Python textfsm 1.2k
# Python sherlock 8
# Go go-tspi 62
# Python kernel-sanitizers 468
# Rust file-header 19
# JavaScript extra-keyboards-for-chrome-os 214
# C++ libprotobuf-mutator 633
# C++ crc32c 498
# Haskell codeworld 1.3k
# Java smali 325
# 不明 android-riscv64 242
# Python unisim 144
# C++ ml-metadata 666
# C kmsan 417
# C# play-asset-delivery-unity 13
# C# play-appbundle-unity 8
# C++ file-based-test-driver 13
# Go oauth2l 709
# 不明 ads-privacy 408
# TypeScript trusted-types-helper 11
# Swift search-in-apps 4
# JavaScript eslint-config-google 1.8k
# Go go-replayers 432
# C++ uVkCompute 257
# Python dfdewey 19
# Verilog CFU-Playground 535
# PHP sqlcommenter 616
# Python picatrix 51
# C++ shadertrap 12
# C++ lldb-eval 86
# Python pasta 359
# HTML LogicLM 29
# C wuffs-mirror-release-c 39
# Python image_mix 16
# Go page-alloc-bench 4
# Python grizzly 69
# Python tf-quant-finance 5.1k
# JavaScript coding-with-chrome 530
# Python html-to-jsonld-converter 5
# Go gopacket 6.7k
# Jupyter Notebook RB-Modulation 402
# Rust briolette 67
# 不明 bbr 5.8k
# Python py-lab-hal 12
# C++ bsynth 20
# 不明 .github 109
# Java snowflake-to-bq-data-transfer-tool 3
# JavaScript password-alert 322
# Shell moodle-on-gcp 72
# Kotlin glance-experimental-tools 185
# Java myanmar-tools 255
# Go k8s-digester 155
# Go splice 65
# Go cc-device-plugin 4
# Python project-OCEAN 55
# Go git-pull-request-mirror 95
# Go weasel 66
# Jupyter Notebook parse-ego4d 7
# Python deepconsensus 252
# Jupyter Notebook deeppolisher 94
# Python makerspace-auth 66
# HTML material-design-lite 32k
# R patrick 143
# C# xr-objects 161
# JavaScript dlc-insight-lab 1
# JavaScript j2cl-protobuf 25
# Go yarsa 1
# TypeScript googlesre 167
# Kotlin android-auto-companion-android 26
# Jupyter Notebook automl 6.4k
# Python gdb_gcore_point 2
# Rust serde_json5 42
# TypeScript emoji-scavenger-hunt 819
# Swift android-auto-companion-ios 16
# C# library-wrapper-unity-common 7
# Rust lottie-tools 2
# C++ speedy 35
# C pebble 4.9k
# Java volley 3.4k
# Go open-sztp 11
# Python pyu2f 84
# C++ marl 2k
# C++ cppdap 182
# TypeScript uem_poc 3
# 不明 new-project 234
# Go go-cmp 4.5k
# Haskell mlir-hs 118
# Go webrisk 78
# TypeScript csp-evaluator 373
# C++ multichannel-audio-tools 95
# JavaScript pprof-nodejs 287
# C hctr2 37
# JavaScript santa-tracker-web 644
# TypeScript jira-to-issues 18
# Rust best 137
# Jupyter Notebook alu-api 1
# Haskell haskell-indexer 101
# Python latexify_py 7.6k
# Swift abseil-cpp-binary 16
# Python fuzzbench 1.2k
# Java jarjar 90
# Java xdtk 38
# C# play-integrity-unity 10
# C# play-in-app-reviews-unity 12
# C# play-in-app-updates-unity 3
# Objective-C++ santa 4.5k
# C# play-core-unity 3
# Dart android-auto-companion-app 15
# C++ orbit 4.3k
# C++ leveldb 38k
# Go ctrdac 13
# Java mail-importer 264
# Go deck 56
# C++ unsmear 95
# C# library-wrapper-unity-openjdk8 7
# Go calblink 43
# Shell kir-holiday-lights 19
# CSS io-connect-2024-ui-workshop 44
# Haskell snaplayout-for-xmonad 6
# Python dfiq 294
# Rust git-tree 45
# 不明 learn_unsafe_rust 279
# TypeScript archat 94
# Kotlin summit-ast 42
# Rust rust-p9 43
# Python spiqa 70
# Rust oxsea 2
# Java re2j 1.2k
# Python megalista 138
# Rust serde_json_lenient 25
# Apex bulk-actions-framework 1
# Python rag-playground 41
# Shell agi-dev-releases 35
# Kotlin fhir-app-examples 54
# Python shopping_insider 29
# Go gnostic-grpc 314
# Go acjs 10
# Go go-react 38
# Go broken-dns 22
# Go xtoproto 58
# Go martian 2k
# Go recursive-version-control-system 31
# C++ spdmd 0
# Go bulk_fhir_tools 63
# Go ondc-opencommerce 24
# Go goblet 181
# Go webpackager 75
# Go apt-golang-s3 49
# Shell fhir-dbt-analytics 58
# C++ vxsig 284
# JavaScript traceur-compiler 8.2k
# Rust vimscript-language-server 401
# HTML cpp-from-the-sky-down 276
# Python tree-math 202
# Go go-streaming-globber 6
# 不明 clusterfuzzlite 509
# Shell ads-bi-suite 18
# C++ tcpgpudmarxd 9
# C# play-common-unity 1
# C# play-unity-plugins 465
# Jupyter Notebook codex 67
# Python sre_yield 187
# JavaScript lintush 59
# C emoji-segmenter 64
# Java unity-anr-plugin 5
# JavaScript imageinwords 223
# Python android-emulator-container-scripts 2k
# C werm 46
# 不明 season-of-docs 579
# Go uuid 5.9k
# Swift android-auto-companion-calendarsync-ios 6
# Jupyter Notebook ionosphere 3
# 不明 takeout 11
# Objective-C promises 3.8k
# JavaScript iba-opt-out-plugin 1
# Jupyter Notebook dopamine 11k
# HTML docci 3
# C compute-virtual-ethernet-dpdk 11
# TypeScript angular-directed-graph 18
# Python skywater-pdk 3.3k
# Go safearchive 64
# TypeScript gts 5.2k
# C++ fuzzing 3.7k
# Python slang-gaussian-rasterization 362
# Java talkback 488
# C++ langsvr 9
# Kotlin coroutine-stacks 144
# Java devtools-driver 16
# Java account-provisioning-for-google-apps 51
# TypeScript chicago-brick 161
# TypeScript tour-of-wgsl 142
# Go crfs 1.4k
# Java cql-on-beam 12
# C++ capsicum-test 45
# Python docker-explorer 548
# Java graphicsfuzz 594
# JavaScript CodeCity 193
# C++ moriarty 6
# Python uis-rnn 1.6k
# Shell purr 155
# JavaScript karma-webkit-launcher 12
# Java yaml-ui-editor 32
# Java supl-client 71
# Java robotstxt-spec-test 23
# Java step49-2020 3
# Java robotstxt-java 47
# Java exposure-notifications-private-analytics-ingestion 12
# Java play-work 85
# Shell grr-doc 307
# 不明 eng-practices 20k
# JavaScript tec-web-assignments 12
# Kotlin webdriver-shadow-dom 2
# JavaScript drive-file-search-fix 5
# Go gousb 919
# Python bayesnf 142
# Kotlin funke-eudi-wallet-prototype 3
# Python vimdoc 304
# JavaScript paseos 15
# TypeScript tsunami 9
# SCSS hrx 49
# JavaScript english-- 7
# C++ clif 981
# Python grrshell 7
# C++ cdc-file-transfer 3.4k
# 不明 devops-governance 83
# TypeScript google-visualization 14
# JavaScript price_visibility_booster 2
# Vim Script vim-codefmt 1.1k
# Java project-gameface 617
# Python Vulkan-Errata 5
# JavaScript ad_language_monitor 5
# Jupyter Notebook cell_img 8
# C++ souper 2.3k
# C audio-to-tactile 103
# Kotlin secrets-gradle-plugin 1.3k
# Python madi 78
# CSS google-api-javascript-client 3.4k
# Go btree 4.1k
# Python it-cert-automation-practice 985
# Rust sxg-rs 85
# C++ lyra 3.9k
# JavaScript schemarama 146
# Shell premium-vs-standard-network-latency 4
# Python lut3d_utils 11
# Rust rust-derive-fuzztest 18
# Jupyter Notebook real-time-intelligence-workshop 27
# C ghost-kernel 227
# Dart ansicolor-dart 104
# C++ libnop 576
# C++ zopfli 3.6k
# Dart flutter.widgets 1.4k
# Jupyter Notebook lifetime_value 365
# Java ExoPlayer 22k
# C++ woff2 1.7k
# Jupyter Notebook pwlfit 40
# Jupyter Notebook haloquest 23
# C++ robotstxt 3.4k
# JavaScript closure-library 4.9k
# C++ omaha 2.6k
# Python pycnite 26
# Python model_search 3.3k
# Python shopping-markup 49
# Python resultstoreui 12
# Python sg2im 1.3k
# Go namebench 923
# Python flight-lab 15
# C++ nccl-plugin-gpudirecttcpx 14
# TypeScript zazu 21
# TypeScript codewords 11
# JavaScript voice-builder 679
# TypeScript dynamic-form 30
# Python werewolf_arena 40
# Rust cargo-raze 481
# Go safetext 150
# TypeScript daguerreotype 9
# TypeScript sgtm-migrator 17
# Python BIG-bench 3.2k
# Python feedloader 13
# Vue wikiloop-explorer 8
# TypeScript nodejs-container-image-builder 73
# TypeScript node-fastify-auto-push 101
# Java streetview-publish-client-libraries 19
# TypeScript defi-for-good-contracts 14
# HTML oodle-demo 83
# Jupyter Notebook making_with_ml 348
# TypeScript centaur 12
# Vue poseshield-tfjs 14
# Python personfinder 540
# Python ai_assisted_display_creative 16
# TypeScript automated-native-creatives 16
# TypeScript budoux-illustrator-script 20
# Shell aoss-django-sample-starter-project 6
# Ruby nanopb-podspec 7
# Java setfilters 10
# Python agamotto 18
# Python balloon-learning-environment 125
# Python seatera 18
# Jupyter Notebook diffseg 327
# C# window-mirror 18
# Python keyword_factory 41
# Python merchant_center_repor_builder 11
# Jupyter Notebook inspiration_tree 77
# Jupyter Notebook brain-tokyo-workshop 1.3k
# Python taxonomy_wizard 13
# Python mandiant-ti-client 19
# Python vertex-pipelines-boilerplate 10
# Python project_cartesian 20
# JavaScript android-emulator-webrtc 149
# VBScript password-sync-support-tool 34
# Go jsonapi 1.4k
# Python ad-manager-alerter 27
# TypeScript looker-studio-dashboard-cloner 36
# Go gcp-scc-iac-validation-utils 2
# C iconvg 682
# Kotlin playhvz 26
# TypeScript assetMG 7
# TypeScript bulkan 7
# Jupyter Notebook evojax 925
# Python telluride_decoding 14
# Go font-go 54
# Java java-time-client 18
# TypeScript project-euphonia-audiotool 27
# 不明 task-oriented-queries 5
# TypeScript peripheral-customization-pwa 7
# Python protobuf-extensibility-for-burp 88
# TypeScript eventid-js 78
# TypeScript node-h2-auto-push 328
# TypeScript js-green-licenses 181
# C gasket-driver 109
# TypeScript wikiloop-doublecheck 83
# JavaScript data-layer-helper 440
# JavaScript dana 117
# TypeScript accname 34
# TypeScript libhidtelephony 12
# TypeScript incremental-dom 3.5k
# TypeScript pixelate 54
# TypeScript conversion-audit 5
# TypeScript data-quality-monitor 38
# Python product-dsa 12
# TypeScript react-schemaorg 506
# Jupyter Notebook android-management-api-samples 34
# TypeScript creative-screenshots 17
# Python dqm 27
# TypeScript fusion-tables-archive-visualizer 33
# JavaScript nodejs-wiki 17
# Python assortment-quality-for-shopping-ads 8
# JavaScript eleventy-high-performance-blog 4.1k
# Python uafcs 4
# Python vsf-time-series 30
# Jupyter Notebook oculi 63
# Java android-uiconductor 125
# TypeScript tamperchrome 4.2k
# Python gov-meetings-made-searchable 33
# Jupyter Notebook patents-public-data 627
# JavaScript tweakr 26
# TypeScript ngrx-visualizer 23
# JavaScript mweb-analysis-tools 8
# TypeScript fusion-tables-drive-export 7
# TypeScript vscode-zxdb 4
# Python gtasks-md 74
# TypeScript triggerator 11
# JavaScript service-worker-detector 183
# Java cronet-transport-for-okhttp 523
# Apex ditto-mocks 97
# Java gps-measurement-tools 803
# JavaScript stijl 43
# Go schedviz 530
# TypeScript grassland 10
# Rust synthesizer-io 36
# JavaScript eslint-closure 33
# TypeScript intermock 1.2k
# C++ mpact-sim-codelabs 4
# Python pybadges 498
# Python uv-metrics 13
# Python caliban 500
# Perl verilogpp 17
# Python t5patches 12
# C++ vpn-libraries 554
# Go go-p11-kit 93
# C ngx_brotli 2.2k
# C psp 276
# TypeScript google-sql-syntax-ts 9
# Python fishy-pdf 11
# JavaScript dv360-spend-monitoring-tool 6
# Python diff-match-patch 8k
# Python hi-lassie 24
# Python lassie 53
# Python lkml-gerrit-bridge 7
# Jupyter Notebook lecam-gan 165
# Jupyter Notebook prog-edu-assistant 33
# Python har-sanitizer 73
# Python pre-commit-tool-hooks 38
# JavaScript jsaction 1.1k
# HTML deepmac 5
# Jupyter Notebook game-changing-assets 3
# Java framework-for-osdu 19
# C++ hintless_pir 22
# C++ jwt_verify_lib 44
# Jupyter Notebook prompt-to-prompt 3.4k
# Jupyter Notebook how-unique-is-whose-web-browser 2
# C++ brunsli 745
# Go gapid 2.2k
# Python report2bq 13
# Python brandometer 10
# Python ldif 320
# C++ pawn 337
# Jupyter Notebook empirical_calibration 45
# Python shuwa 143
# TypeScript tabletopaudio-action 9
# Python hypernerf 943
# Python importlab 177
# Python ota-generator 24
# Python ai_video_dubbing 50
# Kotlin prefab 229
# Python starthinker 173
# Go golden-path-for-app-delivery 18
# C++ ringli 11
# JavaScript oatts 141
# HTML web-starter-kit google/web-starter-kit's
# Python nerfies 1.9k
# Kotlin flexbox-layout 18k
# Shell cityhash 1.2k
# Kotlin intellij-gn-plugin 15
# Go safebrowsing 488
# JavaScript AEUX 541
# C++ highwayhash 1.6k
# Shell amot 3
# Go licensecheck 484
# Java osdetector-gradle-plugin 116
# Python permhash 44
# Python flaxformer 363
# Objective-C GTXiLib 233
# C esh 331
# Java quota-monitoring-solution 52
# 不明 common-multicloud-runtime 0
# 不明 cmrt 1
# JavaScript coding-with-chrome-libraries 24
# Objective-C macops-MOLXPCConnection 26
# Objective-C macops-MOLAuthenticatingURLSession 23
# Objective-C macops-molcodesignchecker 33
# Objective-C macops-molcertificate 36
# HCL example-demos-for-msft-workloads 16
# Python python-adb 1.8k
# C cronutils 119
# C dmabuf_importer_helper 1
# C++ flutter-desktop-embedding 7.1k
# Java Accessibility-Test-Framework-for-Android 499
# Go devx-tools 73
# PHP php-crc32 186
# Java step197-2020 4
# Python adb-sync 1.1k
# Python mint-line-follower 3
# Python gps-babel-tower 8
# Go simhospital 717
# C adiantum 477
# Python visionai 47
# C xsecurelock 914
# Go cel-policy-templates-go 73
# Go mawfs 63
# Python distla_core 3
# JavaScript abstracttext 78
# 不明 mobly-snippet-lib 42
# 不明 skywater-pdk-libs-sky130_fd_pr 28
# 不明 spdm-accelerator-requirement 2
# C++ longbet 24
# Python dexmod 63
# Python space 155
# Shell netbsd-gce 41
# Jupyter Notebook neural-tangents 2.4k
# C++ redgrep 162
# Python binja-hexagon 116
# 不明 hark 9
# Python mobly-windows 4
# C tree-sitter-fidl 4
# Starlark bazel_rules_install 43
# Python putting-dune 10
# Dart hierarchical-state-machine.dart 36
# Kotlin casa-android 270
# HTML security-crawl-maze 163
# Java cordova-plugin-browsertab 117
# Go csv2pprof 2
# C compact_enc_det 239
# Java grafika 6.1k
# Java gwtmockito 160
# Jupyter Notebook navi 59
# C++ eidos-audition 33
# Python alligator2 42
# C++ process-tree 3
# Jupyter Notebook hashtable-benchmarks 111
# Rust json5format 111
# C++ gemmlowp 1.8k
# Java play-licensing 118
# C++ net_http 25
# Python objax 775
# Go safeopen 105
# Go todo-tracks 185
# Go alertmanager-irc-relay 58
# HTML crossmodal-3600 9
# C++ piex 52
# C++ pkcs11test 81
# Python ceviche-challenges 114
# Dart flutter.plugins 117
# HTML DOM-Tutorials 16
# Python memutil 3
# HTML dsg 2
# 不明 zoekt 1.7k
# Java android-lint-performance-probe 157
# Python break-a-scene 525
# Python kinda-tidy 7
# 不明 asml 5
# Rust impl_trait_utils 8
# Shell fhir-dbt-utils 14
# Jupyter Notebook project-eager 21
# Python style-aligned 1.3k
# 不明 gce-rescue 14
# C++ maldoca 66
# Python microscopeimagequality 91
# JavaScript github-owners-bot 50
# ShaderLab valid-avatar-library 51
# Smarty sgtm-ga4-to-bigquery 27
# Objective-C paco 332
# C ghost-userspace 236
# Python waze-ccp-gcp 11
# Java hadoop-migration-assessment-tools 9
# JavaScript outrigger 4
# Verilog skywater-pdk-libs-sky130_fd_io 11
# Java bamboo-soy 48
# TypeScript web-serial-polyfill 137
# JavaScript typograms 1.3k
# C++ network-opt 151
# C++ nccl-fastsocket 122
# Java cbortree 25
# Kotlin apdu 8
# Python ic-modeling-python 1
# JavaScript ads-account-structure-script 27
# 不明 deshell 4
# JavaScript ga4-gtm-migration 119
# Rust libtracecmd-rs 25
# C# EtwToPprof 12
# C++ basis_universal 10
# PHP sqlcommenter-laravel-php 7
# C++ libtrusttoken 15
# Go go-pkcs11 20
# Python github-release-retry 15
# Java java-photoslibrary 113
# Python vertex-ai-nas 30
# Python storybench 51
# JavaScript metamath.js 15
# Python gae-secure-scaffold-python3 32
# Python analytics-settings-database 57
# 不明 platform_benchmarks 17
# Python dynibar 813
# Dart process.dart 52
# JavaScript marzipano 2.2k
# Python multispecies-whale-detection 7
# 不明 oss-vulnerability-guide 139
# C++ osqp-cpp 277
# Java dwh-assessment-extraction-tool 14
# Go go-metrics-stackdriver 31
# C++ magritte 441
# Java mobile-data-download 26
# Python brain_autorl 55
# 不明 usm-voice-transcriber 1
# C++ anonymous-counting-tokens 20
# Smarty sgtm-event-data-filter 24
# Java exposure-notifications-android 529
# Go go-cmdtest 180
# JavaScript custom-bidding-script-builder 11
# Objective-C macops-planb 152
# C++ knusperli 469
# C++ mouse-pose-analysis 13
# Python TensorNetwork 1.9k
# Python trajax 227
# Jupyter Notebook mouse-pose-analysis-dataset 10
# Python splitbrain 20
# Python globalfoundries-pdk-libs-gf180mcu_fd_pr 54
# C++ open-vcdiff 205
# C++ vulkan_test_applications 72
# Python ads-placement-excluder 10
# JavaScript wwwbasic 1.1k
# Kotlin model-verifier-in-kotlin 6
# Python parallel_accel 3
# Python sycophancy-intervention 117
# Python cyanobyte 82
# C++ cpp-smt-wrapper 4
# Python python_portpicker 152
# Python eclipse2017 21
# Python kepler 38
# Go git-appraise 5.3k
# Objective-C GSCXScanner 138
# Kotlin mdoc-credential 9
# HTML video-localized-narratives 60
# Java gradle-thrift-plugin 9
# JavaScript bulkdozer 12
# D re2d 14
# Python gif-for-cli 2.9k
# Dart cronet.dart 119
# 不明 allstar-config google/allstar-config's
# C++ certificate-transparency 882
# Shell aoss-springboot-sample-starter-project 8
# C++ fhir-examples 112
# Rust bevy_skybox_cubemap 17
# Python cvelist 15
# TypeScript mirror-branch-action 25
# Python lasr 172
# Python speech_intelligibility_index 46
# HTML coding-competitions-archive 1.3k
# HTML typedoc-neo-theme 85
# C++ CTAP2-test-tool 56
# Dart ui-exp-dg 14
# Python ukip 546
# TypeScript vscode-bigquery 149
# Rust mundane 1.1k
# Dart dart_cli_script 26
# Go logger 889
# Dart flutter-stager 246
# Go exposure-notifications-verification-server 239
# Go exposure-notifications-server 2.6k
# Go go-intervals 140
# Go segment 10
# Kotlin modernstorage 1.2k
# JavaScript mathsteps 2.1k
# TypeScript postcss-src 4
# C++ flutter-sw-rend 10
# TypeScript fuchsiaware 17
# Java app-metadata-encoder 5
# Python macops 827
# HTML git-appraise-web 223
# Shell gfbuild-angle 11
# C++ gf-layers 7
# Java acai 79
# Java cdep 100
# Rust moveit 168
# Java java-monitoring-client-library 67
# Java software-product-sprint 65
# Java rejoiner 3.7k
# C++ vulkan-performance-layers 57
# C++ fss_machine_learning 10
# Python globalfoundries-pdk-libs-gf180mcu_fd_pv 13
# Rust pix-image-viewer 156
# C# receipts-to-riches-part2 1
# Rust rerast 715
# HCL iap-compute-engine-demo 13
# HCL terraform-google-security-health-checker 15
# 不明 malt-example-models 10
# Python trimmed_match 69
# Makefile gf180mcu-pdk 441
# 不明 language-jsonnet 26
# Java appengine-java-migration-samples 1
# C++ cld3 856
# HTML building-secure-and-reliable-systems 127
# Vim Script vim-jsonnet 161
# Python driblet 19
# Haskell ormolu 13
# Java android-classyshark 7.6k
# Python skywater-pdk-libs-sky130_bag3_pr 18
# Rust forma 2.6k
# 不明 centipede 252
# C++ securemessage 109
# JavaScript groupavail 11
# 不明 sky90fd-pdk 121
# Python tsmok 16
# Dart flutter-stream-extensions 17
# 不明 belief-localization 61
# 不明 globalfoundries-pdk-libs-gf180mcu_osu_sc 8
# Jupyter Notebook skywater-pdk-sky130-raw-data 58
# C# receipts-to-riches-part1 5
# Java v8-snapshot-ghidra-plugin 11
# Python nerfactor 449
# HTML elements-sk 29
# TypeScript common-sk 10
# C lk_onload_stub 8
# C++ liquidfun 4.9k
# Jupyter Notebook data-pills 16
# C++ guetzli 13k
# JavaScript chat-enhanced 9
# Java archive-patcher 540
# Python product_return_predictor 16
# Rust rust-deadlock-avoidance 43
# PureBasic digitalassetlinks 103
# Go tsunami-security-scanner-testbed 9
# LLVM vandalir 42
# Python adh-deployment-manager 5
# Common Lisp lisp-koans 3.2k
# 不明 .allstar 8
# Python ci_edit 228
# Go go-pipeline 100
# Verilog globalfoundries-pdk-ip-gf180mcu_fd_ip_sram 18
# JavaScript lasso 29
# Rust webbundle 101
# Haskell haskell-trainings 1.4k
# C++ EXEgesis 281
# Jupyter Notebook earthengine-jupyter 82
# Python bigspicy 40
# C PINT 18
# TypeScript re2-wasm 75
# TypeScript rtb_creative_filtering_report 4
# Python aistplusplus_api 380
# Java watchpresenter 24
# Python budou 1.2k
# JavaScript end-to-end 4.1k
# Python ipaddr-py 195
# JavaScript gce-machine-type-recommendations 6
# C libsbc 24
# Python hdrnet 851
# Python gke-cloud-dns-tls 15
# C++ usd_from_gltf 572
# Python volux-gan 29
# 不明 rust-design-faq 18
# Swift JacquardSDKiOS 21
# Jupyter Notebook tfjs-mnist-workshop 7
# Python mentornet 323
# Python next-prediction 356
# Java JacquardSDKAndroid 20
# Python python-temescal 24
# C++ pik 834
# Jupyter Notebook TrustScore 177
# Python python-security-manager 36
# C++ memcpy-gemm 16
# Java vertex-ai-benchmarker 10
# Go easypki 593
# Vim Script vim-maktaba 589
# HTML polynomial-practice 5
# Python HyperCompressBench 18
# Python profiling-data-processing-model-isca23-ae 9
# Go monologue 40
# Shell support-case-notifications 12
# Python ml-fairness-gym 316
# 不明 dreambooth 998
# Shell tekton-slsa-demo 9
# C++ mathfu 1.4k
# Dockerfile draft-todo-chariton-dns-account-01 4
# Python omnimatte-sp 11
# Python samurai 121
# Java grpc-java-bazel-minimal 8
# C++ monster-mash 1.3k
# Verilog skywater-pdk-libs-sky130_fd_sc_hd 18
# Go huproxy 422
# Dart pageloader 40
# HTML gumbo-parser 5.2k
# Shell greasy 6
# Vim Script vim-ft-go 54
# JavaScript baby-alligator 3
# Shell copr-sundry 14
# Shell cloud-resource-manager 22
# Dart pub_cache 18
# Java sa360-webquery-bigquery 16
# C++ ndprbrd 39
# Ruby google-id-token 75
# C++ cast-moderator-centipede 10
# Java floody 3
# Objective-C functional-objc 350
# C++ sealedcomputing 8
# C ngx_token_binding 45
# Kotlin iosched 22k
# C++ earthenterprise 2.7k
# HCL anthos-microk8s 30
# Python saka 6
# Python subpar 568
# JavaScript device-access-sample-web-app 34
# Vim Script vim-glaive 77
# JavaScript virtual-authenticators-tab 179
# Python active-learning 1.2k
# Verilog globalfoundries-pdk-libs-gf180mcu_fd_sc_mcu9t5v0 18
# Verilog globalfoundries-pdk-libs-gf180mcu_fd_io 14
# Verilog globalfoundries-pdk-libs-gf180mcu_fd_sc_mcu7t5v0 26
# Python attention-center 121
# Shell backup-dr-custom-roles 4
# Shell profit-bidder 3
# Dart chartjs.dart 143
# Vim Script vim-colorscheme-primary 268
# C google-drive-dokany 33
# Dart charts 2.8k
# Go ubntools 18
# Lua FluidNet 755
# Go gofuzz 1.5k
# Rust minetest_pnr 18
# Dart auto-disposable 14
# Dart tuneup.dart 52
# Dart flutter_minimal_store 23
# Python jax-recommenders 11
# 不明 plb 25
# GLSL randomized-graphics-shaders 7
# Go sshkey-audit 66
# HTML chive-varying-prosody-icml-2019 7
# JavaScript processingjs-ide 22
# Jupyter Notebook applied-data-structures-algorithms 26
# Python referring-manipulation 9
# C++ cpu-check 61
# Dart repository-lifecycle 10
# Dart flutter_async_storage 15
# JavaScript beautiful-audio-editor 93
# 不明 deepdream 13k
# Kotlin peg-typed 4
# C nanolibc 12
# JavaScript blockly-devtools 60
# Python mipnerf 933
# Rust decoder-benchmarks-for-rust 5
# Python asset-inventory-worksheet 9
# Java creatine-ads-inspector 10
# C++ mysql-protobuf 131
# C++ qrisp 11
# Java safe-html-types 60
# Java ios-device-control 43
# C++ liburing_cpp 17
# Python nogotofail 2.9k
# Python tangent 2.3k
# C libsxg 54
# 不明 calliope-paper-robot 10
# C++ zuckerli 28
# Python transitfeed 690
# 不明 roughtime 11
# C++ fplbase 198
# 不明 skywater-pdks 8
# Go hilbert 286
# Rust mcp2221-rs 7
# Python mirandum 12
# Vim Script vim-coverage 104
# Dart dart-json_diff 74
# Python mystyle 129
# Go web-bsd-hunt 36
# C++ vk_callback_swapchain 9
# C++ butteraugli 2k
# Shell spirv-tutor 78
# Rust stm32-bootloader-client-rs 13
# Python gfw-deployments 78
# Python coop-analytics 10
# 不明 fledge-key-value-server 3
# C ms-tpm-20-ref 4
# C++ libprotobuf-mutator-asn1 19
# 不明 open-source-pdks 108
# Python magic-github-proxy 149
# Java codeu-starter-project 12
# Java codeu_project_2018 12
# JavaScript u2f-ref-code 588
# C# google-drive-proxy 87
# C++ google-drive-shell-extension 159
# HTML chive-prosody 5
# Kotlin cross-device-sdk 98
# Java schemaorg-java 75
# Rust crumsort-rs 168
# C++ plusfish 28
# PHP sqlcommenter-php 9
# Java connectedappssdk 9
# Go go-cabfile 9
# PowerShell GCP-deployment-scripts-for-PI-Core 8
# JavaScript WebFundamentals 14k
# Go go-flow-levee 194
# Python chiplets-cost-model 24
# Python chatbase-python 76
# Kotlin kiosk-app-reference-implementation 17
# Python ai-weather-climate 17
# Python viai-sdk 7
# 不明 skywater-pdk-ip-sky90fd_fd_ip_sram 9
# 不明 skywater-pdk-libs-sky90fd_fd_io 4
# 不明 skywater-pdk-libs-sky90fd_fd_pr 6
# 不明 skywater-pdk-libs-sky90fd_fd_sc 5
# 不明 skywater-pdk-libs-sky90fd_osu_sc 4
# Jupyter Notebook one-weird-trick 15
# Python pmax_migration 4
# 不明 stable-retraining-conversational-agents 2
# Go go-pcie-tlp 42
# 不明 globalfoundries-pdks 50
# 不明 globalfoundries-pdk-libs-gf180mcu_fd_bd_sram 10
# C++ HyperProtoBench 18
# Java live-transcribe-speech-engine 1.5k
# JavaScript sxg-validator 4
# R rappor 869
# Python bazel-to-cmake 204
# Python e3d_lstm 205
# Java santa-tracker-android 2.1k
# Go log4jscanner 1.6k
# Python zoom-to-inpaint 21
# Go chrometracing 45
# C DAPLink-port 18
# R causalexpanalysis 20
# R poweranalysis 8
# Java MOE 422
# JavaScript tritious 7
# JavaScript dcm-trix-addon 12
# Go argtail-check 7
# Go squidwarden 60
# Python qhbm-library 43
# 不明 BEGIN-dataset 39
# C++ randen 337
# Rust tock-on-titan 56
# Makefile makerspace-lipo-charger 9
# C++ ion 1.4k
# Python makerspace-partsbin 17
# Python import-mailbox-to-gmail 346
# Python tf_mesh_renderer 497
# Python ctfscoreboard 171
# Python cocoapods-size 237
# Scala cluster-scheduler-simulator 170
# Kotlin dokka 16
# C++ etc2comp 387
# Go periph 1.7k
# Python tensorflow-recorder 180
# Python hotel-ads-etl-tool 9
# JavaScript budget-protector 5
# Java jsontoken 18
# Java infra-structured-map 8
# Java martian-java 12
# Java i18n_sanitycheck 14
# Java nel-reporter-java 15
# JavaScript gtm-currency-rates-sync 14
# C++ embed-dart-vm 99
# Kotlin Kotlin-FirViewer 51
# C++ cwisstable 158
# Python swift-jupyter 623
# Rust bongo 23
# Shell gfbuild-shadertrap 3
# Python google-my-business-samples 133
# Swift swift-benchmark 936
# Python tmppy 34
# HTML radium 9
# C++ libcppbor 8
# Java AndroidForegroundCompat 65
# Python airdialogue 45
# C++ aistreamer 150
# 不明 skywater-pdk-libs-sky130_fd_pr_reram 41
# Python sample-sql-translator 52
# Shell gfbuild-SPIRV-Tools 11
# JavaScript vapso 5
# Starlark llvm-bazel 170
# C++ asylo 980
# Go knative-gcp 161
# Python fractribution 56
# Python github_actions_playground 8
# C++ nanopb-cpputest-comparators 4
# Kotlin tweakr-codelab 1
# Kotlin where-am-i 37
# Jupyter Notebook responsible-innovation 9
# Python blockbuster 5
# Shell ekep-analysis 8
# HTML android-gradle-dsl 785
# Java gitiles 603
# Kotlin security-annotation-tools 7
# Python rfmt 86
# Java java-run 5
# Dart quiver-log 24
# C hardware-perfcounter 93
# Shell gfbuild-graphicsfuzz 7
# JavaScript dv360_feature_adoption 6
# C++ cortex-demos 12
# C++ universal-dash-transmuxer 55
# Jupyter Notebook physics-math-tutorials 10
# 不明 longt5 2
# Go gcb-tools 5
# TypeScript scrollytell 64
# Python wide_bnn_sampling 7
# Python dynamic-video-depth 270
# Go gnostic-go-generator 49
# C# IdleWakeups 10
# Shell java-video-live-stream 3
# Java depan 91
# Python disapproved-ads-auditor 18
# Haskell hs-ten 4
# Haskell hs-portray 6
# Go dtraceStacksToPprof 6
# Go grumpy 11k
# TypeScript web-prototyping-tool 29
# Rust rust-async-coap 50
# Java agera 7.2k
# JavaScript html-quiz 114
# TypeScript fledge-shim 23
# C++ rainbow 6
# Python secret-manager-with-sendgrid 10
# 不明 standard-payments 5
# Python vulncode-db 577
# 不明 ktsan 569
# JavaScript inspectorspacetime 175
# Python bi-tempered-loss 147
# Go go-cpy 43
# Rust exists-ref 4
# C++ nucleus 796
# Dart crclib.dart 23
# 不明 overcoming-conflicting-data 4
# Go pezl 6
# Python aiyprojects-raspbian 1.7k
# C++ cuckoo-index 129
# Go goexpect 758
# Dart observable 60
# C# mechahamster 509
# C++ REAPER 407
# C++ ghost-dataplane 9
# Jupyter Notebook music-synthesizer-for-android 434
# Python ga-serverless-streaming 14
# Python pyaedj 9
# Python structured_labels 5
# Jupyter Notebook svcca 638
# Haskell orthotope 11
# JavaScript ezgantt 102
# JavaScript videotts 3
# Haskell hs-dependent-literals 4
# JavaScript floodlight-audit 11
# C nginx-sxg-module 83
# Java climb-tracker 33
# Haskell hs-numeric-logarithms 3
# Haskell hs-collate 3
# Haskell hs-batching 3
# Haskell hs-fin-vec 3
# Haskell hs-niche-containers 3
# Haskell hs-attenuation 3
# Haskell hs-wrapped 3
# Java closure-stylesheets 315
# Go cloudprober 1.4k
# 不明 h2e_technical_documentation 467
# C++ integers 188
# C++ makani 1.2k
# Python youtube-8m 2.4k
# Python amt-forensics 49
# 不明 healthcare-text-annotation 43
# AppleScript PS3ControllerAutoSleep 11
# 不明 skywater-pdk-libs-sky130_fd_bd_sram 22
# C++ paragraph 14
# Java private-retrieval 41
# Python google-visualization-python 135
# Dart flutter_flux 376
# Go go-pbmoney 38
# C++ farmhash 644
# 不明 actions-on-google-template-sdk 14
# Java startup-os 687
# HTML phoneme-aligned-graphemes-in-tts 4
# MATLAB RED 116
# C++ segy-stack 27
# PHP php-photoslibrary 92
# Rust xsecurelock-saver-rs 14
# Python floq-client 19
# Python upvote_py2 452
# Go gomemcache 22
# Python autocjk 13
# Java exposure-notifications-internals 139
# Shell gfbuild-amber 5
# Python lexical-masks 8
# C++ mimosa 21
# JavaScript aistplusplus_dataset 16
# Shell gfbuild-glslang 7
# Python android-cuttlefish-authentication 4
# C++ language-resources 386
# C++ infact 74
# HTML localized-narratives 86
# Dockerfile platforms-bios-buildenv 6
# Python x509test 43
# JavaScript percy-node 19
# Dart web_notifications.dart 13
# C++ LLpatch 37
# Python compare-codecs 50
# Python certificate-transparency-rfcs 80
# Dart librato.dart 5
# Python kasane 172
# Go cloud-print-connector 765
# Java gcm 823
# Scheme schism 1.3k
# Go concourse-resources 29
# Objective-C gtm-oauth2 127
# Go traceout 19
# Go go-patchutils 26
# Makefile disable-keyboard-shortcuts 35
# Python aiyprojects-raspbian-tools 12
# Jupyter Notebook explaining-in-style 223
# C fuzzer-test-suite 1.5k
# C++ vulkan-pre-rotation-demo 24
# Shell gfbuild-llpc 7
# Kotlin intellij-kotlin 4
# Go emu-control 7
# Python deluca-lung 5
# Python ehr-predictions 107
# HTML aichoreographer 20
# Python makerfaire-booth 14
# JavaScript lovefield 6.8k
# Go testimony 108
# Vim Script vim-selector 17
# C++ cpp-proto-builder 4
# 不明 open-chiplet 27
# C++ trusted-worklet-server 4
# C++ trusted-key-value-server 3
# Python prediction_framework 43
# Jupyter Notebook deluca-igpc 7
# HTML cssi-labs 34
# Go stenographer 1.8k
# HTML usb-cereal 92
# JavaScript rtb_troubleshooting_connector 2
# Jupyter Notebook nsc-tutorial 4
# Haskell hrepl 49
# JavaScript dv-3po 5
# Python CSP-Validator 27
# C++ gsrsup 5
# C AFL 4k
# Go keytransparency 1.6k
# Go gitprotocolio 400
# C libpam-policycache 34
# Jupyter Notebook pikov 17
# Jupyter Notebook federated-ml-health 14
# Java rich-test-results 55
# Python neural-light-transport 277
# Java codeu_project_2017 98
# Shell gfbuild-swiftshader 9
# Python python-cloud-utils 23
# Java domaintest 71
# TypeScript mysteryofthreebots 44
# Python dnae 9
# JavaScript last-fm-dashboard 16
# Java guice-aqueduct 11
# 不明 hana-bq-beam-connector 6
# Python stress_transfer 8
# Python arithmancer 63
# CSS contentbox 35
# 不明 maps-for-work-samples 140
# Java java-sourcetools 8
# Java gwteventbinder 141
# Python usbinfo 40
# Dart flutter-provide 803
# JavaScript closure-builder 65
# JavaScript dv360-api 36
# C resumable-assert 176
# JavaScript auction-insights-visualization 17
# HTML asylo-site 22
# C++ asylo-examples 23
# JavaScript shenzhen-go 464
# Jupyter Notebook dv360-automation 20
# Swift swiftlogfirecloud 18
# MATLAB bband-adaband 18
# Python skywater-pdk-actions 13
# Makefile openssl-tests 14
# Java hover 2.6k
# C opensmartbutton 6
# JavaScript talos-dv360 5
# C hammer-kit 78
# 不明 devsite-template 3
# Rust mosaic 17
# C tcpauth 100
# JavaScript recog 5
# Python transperf 210
# Python rescue-tools-reiserfs 5
# Python localsubnetsetd 6
# Java experience-accessibility 25
# C++ ihmehimmeli 144
# Shell kube-node-tracer 9
# C++ fidi 10
# 不明 proto-quic 1.2k
# TypeScript transmat 507
# Shell git-presubmit-linter 41
# Python pyvisionproductsearch 9
# Go blueprint 352
# C++ mysql-ripple 377
# Verilog skywater-pdk-libs-sky130_fd_sc_hdll 7
# Verilog skywater-pdk-libs-sky130_fd_sc_hs 5
# Verilog skywater-pdk-libs-sky130_fd_sc_hvl 4
# Verilog skywater-pdk-libs-sky130_fd_sc_ls 5
# Verilog skywater-pdk-libs-sky130_fd_sc_ms 5
# Verilog skywater-pdk-libs-sky130_fd_sc_lp 8
# Java coapblaster 39
# Lean formal-ml 25
# Starlark cabal2bazel 42
# MATLAB ffcc 217
# Python retriever_parsing 9
# JavaScript custom-tab-groups 4
# Jupyter Notebook prog-edu-assistant-quizzes 6
# Python pygtrie 824
# Python pcbdl 182
# HTML look-before-you-speak 5
# Jupyter Notebook applied-machine-learning-intensive 150
# Python tirg 304
# Python autobidding-readiness-monitor 9
# C++ merror 6
# JavaScript actions-on-google-flashcards-template-sdk 9
# JavaScript actions-on-google-trivia-template-sdk 18
# Java splot-java 16
# Go hotel-booking-api-validator 19
# Go googlesource-auth-tools 17
# 不明 starlark-rust 193
# C++ protodatastore-cpp 5
# Python dspl 63
# Python pinject 1.3k
# Python wasserstein-dist 73
# Python dotty 49
# Go go-pcie-screamer 30
# Go sge-monorepo 72
# C++ http_pattern_matcher 5
# Java brailleback 33
# JavaScript hubvantage 6
# Python example_extrapolation 9
# C++ security-research-pocs 1.9k
# Jupyter Notebook ga360-bqml-toolkit 8
# Python pytruth 159
# 不明 android-emulator-m1-preview 1.9k
# Jupyter Notebook nitroml 43
# Shell perforce-utils 9
# Dart arrow-logo 15
# C stm32_bare_lib 133
# C usbmon 61
# Python timecast 16
# Python tcav-for-ehr 6
# Java dicomproxy 7
# CMake idaidle 31
# JavaScript forklift 10
# C++ ftc-object-detection 43
# Python containerregistry 212
# Swift open-location-code-swift 49
# C midi-dump-tools 30
# 不明 sky-optimization 56
# Python image-supplemental-feed-creator 3
# Python compare_gan 1.8k
# Shell zeroshell-linode 14
# Python apis-client-generator 162
# Python gae-secure-scaffold-python 111
# C++ dart-gl 92
# 不明 network-mapper 52
# C++ mako 57
# C++ sling 1.9k
# JavaScript tie 361
# Python citest 60
# Python spindle-dv360 13
# JavaScript canvas-5-polyfill 192
# JavaScript trueview-sdf-generator 5
# Python mannequinchallenge 496
# Go skicka 1.3k
# Python cauliflowervest 278
# JavaScript vsaq 856
# HTML StrawNet 4
# Python retiming 176
# C++ aistreams 7
# C++ safeside 505
# Swift blockly-ios 409
# CSS open-gantry 10
# 不明 swift 836
# Python coursebuilder-core 147
# Python hypebot 16
# Python python-lakeside 47
# C++ path-auditor 252
# Haskell xscreensaver-dbus 4
# Python tim-gan 12
# Swift swift-structural 33
# C++ spherical-harmonics 551
# Jupyter Notebook spatiotemporal-graphnn-tf 6
# C reftable 37
# Python google-reauth-python 12
# JavaScript vogon 108
# ...
# JavaScript allied-oscillators 9
# Dart create-framework 6
# JavaScript wayback-machine-button 11
# JavaScript certificate-maker 126
# 不明 night-sight 82
# C++ galogen 51
# JavaScript chatbase-node 80
# JavaScript guava-js-umd 6
# Python NeuroNER-CSPMC 12
# TeX cxx-std-draft 53
# Python revisiting-self-supervised 353
# Python jacs 13
# Java cameraview 4.7k
# JavaScript gulp-google-closure-deps 4
# Go gerrit-linter 27
# Python sprockets 11
# Objective-C restor 226
# JavaScript blockly-experimental 8
# Python OctoPrint-LEDStripControl 64
# Python OctoPrint-TemperatureFailsafe 27
# Python OctoPrint-HeaterTimeout 13
# JavaScript palette.js 589
# Java certificate-transparency-java 41
# Python AppSpeedIndex 13
# C++ gpu-runtime 18
# Python gcnn-survey-paper 174
# Dart apps_script_tools 26
# Objective-C macops-keychainminder 95
# Python embedding-tests 17
# JavaScript tracing-framework 2.6k
# Go netstack 3.1k
# Python multi-task-architecture-search 12
# Python pyringe 1.6k
# C eddystone 3.1k
# C++ statechart 121
# Python deputy-api-python-client 9
# Python checkers 17
# Go shlex 190
# Python nixysa 10
# C++ szl 70
# R abpackage 68
# Go gps_data_solutions 4
# Go sredocs 48
# Go tiff 70
# 不明 google-api-ruby-client-samples 330
# Python gpu-mux 42
# Python jarvan 4
# Python enjarify 2.7k
# Go orderedcode 41
# JavaScript wikiloop-wikidata-game 5
# JavaScript automation-inspector 29
# TSQL floog 6
# 不明 icing-search 3
# Shell distributed-git-forks 22
# HTML phase-prediction 4
# Python campaign-manager-bulk-uploader 10
# C++ swift-lldb 10
# C++ swift-clang 8
# LLVM swift-llvm 8
# C swift-corelibs-libdispatch 5
# C swift-corelibs-foundation 5
# Java mr4c 907
# Python graph-gen 6
# JavaScript sa360-bidbyweather 5
# Swift swift-corelibs-xctest 5
# 不明 gfbuild-SPIRV-Cross 3
# Java MOE-py 7
# Python cloud-function-edit-drive-permissions 16
# R GeoexperimentsResearch 140
# C++ image-compression 78
# HTML gdata-python-client 450
# Java pixelvisualcorecamera 115
# Vim Script vim-searchindex 369
# Python retrieval-qa-eval 42
# HTML cap-library 86
# JavaScript pulito 43
# Python neural_rerendering_in_the_wild 208
# C++ rxcppuniq 13
# Dart charted 157
# Go boundedwait 7
# 不明 fleetspeak-doc 4
# Shell earthstudio-ffmpeg-automator 11
# JavaScript page-timer 100
# Python dpy 63
# C++ crunchy 126
# C++ dimsum 171
# Python copper 16
# C++ cpix_cc 16
# Java intellij-protocol-buffer-editor 20
# Vim Script vim-codereview 75
# Vim Script vim-syncopate 90
# Kotlin grpc-kapt 26
# Swift swift-package-manager 8
# Java webview-local-server 109
# C kleaver 9
# Go gocw 19
# Python pyctr 23
# Java blockly-android 680
# Java android-kerberos-authenticator 32
# Objective-C uiimage-additions 25
# Go emitto 13
# Python stereo-magnification 406
# Python ldpush 37
# 不明 googlemock 433
# Go battery-historian 5.4k
# Python graph_distillation 66
# Python byterun 17
# Java wear-sensors 52
# Java wear-screeninfo 29
# Java wear-displaylock 5
# JavaScript cm-user-tool 5
# C science-journal-arduino 150
# Go nel-collector 40
# C++ google-api-cpp-client 303
# C++ libcxx 192
# Go vectorio 98
# Java openjdk-kerberos 10
# C++ astc-codec 73
# Python atlassian-addons-audit-sheet 11
# Python protorpc 69
# Java kiwi-solver 53
# HTML cssi-blogasaurus 7
# C++ gpu-emulation-stress-test 79
# Rust rust-shell 225
# Go git-phabricator-mirror 30
# Go prometheus-slo-burn-example 142
# C++ bookbot-navigation 13
# Python android-wear-stitch-script 39
# Python squires 15
# JavaScript web-activities 51
# 不明 keyczar 1.1k
# Python neural-logic-machines 293
# Java sha1dc-jni 5
# C++ flatui 651
# C++ motive 202
# Python expt-analysis 7
# Kotlin chromeosnavigationdemo 10
# Dart github-issue-mover 612
# C++ gjstest 129
# Go godepq 335
# Shell harpia 15
# Java pjflate 6
# Perl us-altgr-intl 16
# Java error-prone-javac 36
# Java gwt-charts 25
# Python git-patrol 9
# Perl horenso 63
# Python n-digit-mnist 46
# JavaScript pagespeed-inslides 58
# Go go-structeditor 41
# Go navc 60
# Objective-C ios-chatbot 93
# JavaScript codemirror-mode-jsonnet 19
# PowerShell ps_log 15
# Python support-tools 29
# 不明 wikiloop-datasets 7
# Shell heroku-buildpack-bazel 8
# Go skylark 1.2k
# Go image-rebase 38
# Kotlin zsldemo 20
# JavaScript easy-grid 37
# Go keps 9
# Python hyou 109
# Go shipshape 270
# 不明 glslang 36
# C quark 10
# Java vr180 55
# Go orismologer 11
# JavaScript chord 28
# JavaScript qpp 43
# Go go-microservice-helpers 418
# JavaScript node-sec-roadmap 173
# Java gdata-java-client 136
# Objective-C gtm_load_timer 44
# JavaScript hangouts-chat-bot-cloud-function-nodejs-example 16
# Java googletv-android-samples 165
# JavaScript dbm-lineitem-copier 13
# JavaScript dcm-bulk-trafficking 11
# 不明 google-api-objectivec-client 303
# JavaScript radioreceiver 411
# Python meta_tagger 48
# Haskell btls 15
# C++ opuscpp 28
# Go credstore 87
# 不明 khll-paper-experiments 12
# Go link022 121
# Java capillary 500
# Python active-qa 344
# Python python-dimond 31
# C++ detectorgraph 46
# TypeScript node-dependency-analysis 16
# C++ syzygy 377
# Java physical-web 6k
# HTML ioweb2016 519
# Go blue-green-deployment-controller 53
# JavaScript cornerstone 7
# Shell appengine-jenkins 36
# JavaScript Safelight 22
# Python blkcgroup 11
# Python cpython-pt 12
# Java protobuf-dt 40
# C++ cpp-netlib 344
# C++ mysql 52
# C++ sawbuck 112
# 不明 uribeacon 410
# C++ ohmu 107
# PHP recki-ct 551
# Python url_diff 98
# C++ filesystem-proposal 19
# Ruby developer.github.com 23
# Java helloargdx 56
# Python emoji4unicode 53
# Python closure-linter 113
# C++ ced 58
# Python mozart 12
# Python python-yaml-config 14
# Python cloud-berg 26
# R fast-optimized-community-significance 5
# Python binplist 53
# Go svalbard 35
# Go go-write 3
# JavaScript cornerstoneWADOImageLoader 5
# JavaScript cornerstoneTools 5
# JavaScript sa360-bulk-editor 5
# Go election-au-2016 100
# Rust fancy-regex 165
# HTML realestate10k 6
# Python asymproj_edge_dnn 25
# C# google-gdata 15
# Scala bottlerocket 110
# Python pandas 27
# Python cog 44
# JavaScript bottery 3.3k
# JavaScript sa360-flightsfeed 13
# Python audio-sync-kit 110
# Go BucketServer 7
# C# ORFConverter 5
# C# chatbase-dotnet 22
# C dtask 27
# HTML virtual-tutors 6
# JavaScript ioweb2015 680
# Go minions 132
# Objective-C gdata-objectivec-client 186
# Objective-C macops-MOLFCMClient 13
# JavaScript detangle 171
# C pg_page_verification 110
# Python layered-scene-inference 87
# Makefile chaps-linux 37
# JavaScript amp-toolbox 12
# C++ quickshift 70
# Jupyter Notebook web-audio-recognition 83
# Shell coursebuilder-resources 15
# C 0x0g-2018-badge 19
# JavaScript dbm-trix-addon 6
# Python fplutil 335
# 不明 coursebuilder-releases 26
# Java google-visualization-java 34
# Shell asr-recipes 17
# Go identity-aware-prober 12
# C++ xrtl 131
# C token_bind 19
# Python differentiable-atomistic-potentials 56
# Python swift-integration-tests 6
# C swift-compiler-rt 5
# C++ swift-llbuild 5
# C swift-cmark 5
# Jupyter Notebook maddpg-replication 32
# 不明 node-armor 4
# JavaScript virtualdesktops-extension 24
# C++ nips_assignments 14
# Shell sparrowhawk 212
# C++ zooshi 291
# JavaScript http_prefetching 8
# C kv-s3105c 6
# Kotlin fastboot-mobile 81
# R amss 50
# Java search-samples 549
# Rust abstreet 36
# Python dl_bounds 17
# JavaScript chrome-tabber 14
# 不明 beacon-platform 391
# JavaScript dcm_bulk_onboarding 7
# C++ fast-simple-lcsk 21
# Python dcm-video-uploader 9
# Java TouchTime 39
# HTML uniflow-polymer 165
# Java rally 38
# Python teknowledge 30
# C++ clerk 38
# C ahdlc 14
# Python aperture_supervision 33
# Java YetAnotherChatApp 9
# C++ grittibanzli 27
# JavaScript ds-trix-addon 16
# Rust hat-backup 252
# TypeScript angular-sticky-element 22
# Python vae-seq 177
# JavaScript cloud-cup 23
# Java cloud-cup-android 51
# 不明 fest 10
# Python decoupled_gaussian_process 24
# 不明 safevarargs 7
# 不明 opentest 3
# Python encrypted-bigquery-client 175
# Python rbe-integration-test 6
# TypeScript chained-promise 53
# R synergyfinderengineered 8
# JavaScript amp-client-id-library 11
# Go go-trace 31
# HTML hell0world-curriculum 7
# Jupyter Notebook intelligent_annotation_dialogs 29
# JavaScript cornerstoneMath 7
# Python burst-denoising 247
# Python generativemloncloud 58
# TypeScript aiyprojects-deeplearn-tensorflow 39
# JavaScript tensorflow-tools 17
# 不明 hugeml 6
# Coq coq-bpf 19
# Java pinotify 6
# Java CallBuilder 105
# Python catnip 26
# Verilog yaricv32 11
# Objective-C unigem-objective-c 25
# HTML speech_style_transfer 4
# Dart perf_api.dart 9
# Go golden 54
# C latency-benchmark 446
# OpenEdge ABL joint_vae 36
# Python stumblybot 25
# C++ mt 52
# JavaScript cornerstoneWebImageLoader 5
# Dart streamy-dart 61
# JavaScript dicomParser 7
# C++ vulkan-cpp-library 250
# Verilog bbcpu 16
# Shell dev-on-chromeos-gce-setup 7
# Python pbvi 8
# C++ capture-thread 100
# C pblog 29
# Python text2text 55
# 不明 ce-open-data-set 8
# JavaScript voice-iot-maker-demo 69
# Python terminal-app-function-keys 89
# JavaScript FakeMaker 22
# Python genomics-protos 13
# Python clicktrackers-panel 7
# C yara-procdump-python 11
# Go streaming_hdp 4
# Python coursebuilder-android-container-module 23
# Scala sync3k-server 21
# JavaScript tern-closure 33
# Go helm-broker 33
# C++ ndash 40
# Python VRD 6
# TypeScript sync3k-client 19
# Go acme 382
# Dart dart-sync-webdriver 22
# Dart dart-sync-socket 25
# Python Legilimency 114
# Python mipsqa 26
# Java devicehub 11
# Shell gtd-txt 21
# Python bitutils 16
# Ruby sonic-midi 17
# Python gumbel_sinkhorn 76
# PHP arc-xcode-test-engine 35
# TypeScript energystrategies 15
# Go marmot 189
# Clojure clojure-turtle 428
# 不明 dev-on-chromeos-che 5
# Shell dev-on-chromeos-openvpn 12
# Java keytransparency-java 6
# Python bocado 9
# Python anvil-build 58
# 不明 river 4
# JavaScript trix-auto-complete 17
# R MAB 38
# Idris idris-protobuf 32
# Jupyter Notebook energysimulation 72
# Go pyrios 61
# Java thread-weaver 309
# Shell cwd_jmp 8
# JavaScript kratu 283
# Java codeu_coding_assessment_b_2017 9
# Emacs Lisp coverage 28
# 不明 ts-gulp 2
# 不明 git-annex-external-gcs 4
# KiCad Layout makerspace-emonth 8
# HTML paper-gui 51
# Java testrunner-rosemary 3
# Java spline 28
# HTML creatism 29
# Dart mockable_filesystem.dart 12
# Go okay 22
# Go metaserver 10
# Go microdhcpd 15
# Go pubkeystore 23
# HTML unimorph 20
# Python GL-Shader-Validator 40
# Python light-my-piano 89
# Go grr_go_client 5
# Go fury 35
# Go grr_go_api_client 5
# Python rttcp 33
# JavaScript functions-demo 6
# Python packet-queue 31
# Java easybundler 54
# Python chkstream 18
# R glmmplus 12
# Java codeu_coding_assessment_2017 10
# HTML address-geocoder-js 11
# Bison classp 169
# C++ xmpmeta 19
# C++ depth_fusion 18
# JavaScript amp-pwa-demo 113
# Python Zhi 28
# JavaScript agata 14
# JavaScript prerender-test 15
# C audit-normalmap 15
# C++ varstruct 18
# C++ emre 13
# Python simple-reinforcement-learning 58
# Ruby homebrew-google-authenticator 29
# Python request-test 6
# 不明 blockly-repo 10
# C++ pindrop 142
# 不明 goldfinch 64
# C++ scene_lab 57
# C++ corgi 251
# HTML dropzone-polyfill 5
# JavaScript ot-crdt-papers 249
# Java windowtester 19
# C fpc 29
# Go fchan-go 311
# C xdelta3-decoder-js 13
# Shell appengine-phabricator 19
# C++ cpp-frp 69
# MATLAB yang_vocoder 91
# Elm keystone 31
# JavaScript adapt-googleanalytics 8
# C++ deepboost 154
# 不明 mcic-coco 24
# Go readahead 136
# Dart source_transformer.dart 9
# Python mcafp 38
# Objective-C gtm-oauth 24
# C++ morphie 23
# C++ libgep 55
# Python smilesparser 13
# 不明 built_json.dart 19
# HTML conferenceDB 9
# JavaScript indexable-pwa-samples 56
# 不明 enum_class.dart 15
# 不明 sass_generator 4
# C vpn-reverse-tether 190
# Python protocall 13
# 不明 transliteration 56
# Protocol Buffer power-traces 8
# JavaScript indexed-db-as-promised 26
# 不明 gotrace 21
# Go cameraraw 26
# JavaScript everythingisconnected 19
# C++ libkml 97
# JavaScript geovelo 44
# Python gfw-toolkit 29
# Python googleapps-message-recall 16
# Objective-C macops-MOMenu 47
# Java dart2java 61
# Shell param_runner 4
# JavaScript gde-speakersbureau 7
# Java AppUpdateTrackerLib 7
# Rust rustcxx 509
# JavaScript dualhttp 22
# Go go-webdav 70
# JavaScript dorusu-js 40
# Go identity-toolkit-go-client 57
# Protocol Buffer dynamex-proto 7
# 不明 auto-common 5
# 不明 auto-service 5
# 不明 auto-factory 5
# Eagle prudaq 123
# Python realtime-help 20
# JavaScript pepper.js 324
# JavaScript instant-hangouts 184
# Java LiquidFunPaint 166
# Java easy-gwt-mock 13
# Go gofountain 110
# C++ VoltAir 317
# C bzip2-rpc 14
# C++ gipfeli 117
# Go go-circuits 15
# Puppet rpki-mgmt 6
# Java simplecfg 11
# C++ maketrace 19
# JavaScript Chrome.Docs 27
# C bluesky-watchface 11
# Go slowfs 58
# PHP arc-jazzy-linter 18
# Python merge_pyi 15
# Go drone-firebase 14
# OpenSCAD cncmicroscope-cad 15
# C# access-bridge-explorer 126
# 不明 gitwf 4
# PHP arc-proselint 17
# 不明 channel-id-enclave 33
# JavaScript generator-goro 24
# C++ xpaf 153
# 不明 google-empty-test-module 3
# Java cloud-reporting 8
# Java reagera 13
# Jupyter Notebook py-decorators-tutorial 31
# JavaScript identity-toolkit-node-client 30
# Shell GOS-conventions 8
# Java identity-toolkit-java-client 37
# C jalic 11
# PHP arc-regex-line-length-linter 8
# Ruby identity-toolkit-ruby-client 10
# C file-system-stress-testing 104
# C linux-sensor 32
# 不明 multibox 307
# 不明 offline-content-packager 35
# Shell crush-tools 150
# Dart flutter-data 11
# Python resolver-library 7
# C++ hops 11
# JavaScript kythe-cloud9 7
# 不明 physical-web-core 3
# 不明 flooefi 10
# Dart serialization.dart 32
# Objective-C templatekit 19
# C++ metrosvg 13
# Python paramgmt 85
# C++ pienoon 438
# Java translation-cards 17
# C++ topdown-btg-preordering 16
# 不明 openpgp-interop 8
# JavaScript appengine-codiad 39
# Go godata 26
# Java opentest4j 5
# PHP identity-toolkit-php-client 37
# 不明 google-maven-parents 6
# Python identity-toolkit-python-client 32
# Java Refaster 54
# Elixir strabo 60
# Go http2preload 20
# Python checkers_classic 7
# JavaScript node-nest 4
# Java intellij-cmdline-vcs-plugin 4
# Go docopt-scripts 6
# 不明 xpra-upstart 3
# AppleScript steamkeysactivator 29
# Ruby homebrew-xpra 9
# Python shipshape-demo 4
# C++ hashing-demo 29
# C++ autopiper 48
# 不明 inception 877
# Haskell clang-lens 20
# JavaScript crisis-info-hub 35
# Dart dart-immutables 6
# C streamhtmlparser 17
# Objective-C pods-helper 5
# Python cluster-insight 99
# PHP freebase-wikidata-converter 63
# C snappy-start 450
# Groff capsicum-man-pages 10
# Rust rust-multihash 62
# 不明 organ-donor-app 3
# 不明 trace-viewer 491
# C++ rowhammer-test 984
# Java ferret 8
# JavaScript module-server 565
# Ruby autoparse 146
# Java android-studio-check 14
# JavaScript chromeos-filesystems 125
# Go gojiraw 16
# Python terminal-py 7
# C++ lmctfy 3.4k
# Dart dart-shapeshift 13
# R calenviroscreen 8
# C++ cncmicroscope-code 24
# JavaScript o3dtoydefense 8
# JavaScript epr 16
# JavaScript codename-mvsv 9
# Python io-captions-gadget 5
# Java ytstatistics-demo 5
# C++ sensei 55
# Dart comid 15
# Dart service_worker.dart 9
# 不明 google-visualization-issues 286
# Dart dart-doc_coverage 7
# JavaScript voter-info-tool 7
# JavaScript chrome-language-immersion 46
# Python coursebuilder_xblock_module 17
# Python py-html-contextual-escaping 4
# HTML json-sans-eval 7
# Python mysql-tools 212
# C++ refr 28
# Python coursebuilder-hello-world-module 8
# Emacs Lisp dart-emacs-plugin-unsupported 12
# 不明 older-mirrored-patches 4
# Python objectfilter 4
# Java retrofit 43
# Java nfc-smart-tag 12
# Processing irrduino 51
# Perl reportlatency 6
# JavaScript gmailsnooze 16
# 不明 deliberate 4
# 不明 network-visualizer-x 5
# 不明 reboot-somalia 3
# 不明 citizen-x 5
# Python pytypedecl 66
# Erlang rysim 7
# 不明 jsontoken-tmp 3
# 不明 go-shlex 5
# Java zarathustra 14
# Haskell pull-request-mailer 45
# C++ elfling 25
# Vim Script vim-ft-vroom 12
# Java picview-for-android 51
# Java picasa-app-demo 10
# 不明 web-starter-kit-extras 71
# Java simple-pedometer 77
# Java sensor-data-collection-library 46
# Python ashier 29
# Python coursebuilder-lti-module 16
# Dart episodes.dart 14
# Dart polymer-dart-log-controller 8
# Python ebola-tools 15
# 不明 pubsubhubbub 6
# Dart dart-tagtree 78
# JavaScript turing-doodle 170
# Python linear-book-scanner 81
# Java java-thread-sanitizer 76
# 不明 gin 5
# 不明 go-glicko2 5
# C++ rct-automation 23
# Haskell Idris-dev 9
# Gosu forcefield 48
# Dart dart-gif-encoder 28
# R glassbox 22
# 不明 coursebuilder-learning-analytics 5
# R NLSdata 8
# 不明 jenkins-flaky-test-report 5
# Python build-debian-cloud 35
# Dart dart-collab 47
# Python wheelbarrow 11
# 不明 photo-sphere 4
# 不明 oss-bench 6
# Java heartbleed-burp-extension 13
# Python lab_device_proxy 39
# 不明 gdal-autotest2 4
# Java patchfield 277
# 不明 googleapps-password-generator 27
# 不明 YouCompleteSubl 2
# 不明 favcolor-findidp 5
# Python appengine_xblock_runtime 19
# Python memcache-collections 66
# 不明 course-builder 5
# Java favcolor-android 40
# JavaScript systemjs 64
# 不明 favcolor-ios 5
# Dart pixelcycle-sample-app 10
# 不明 container-rfc 11
# Dart gae-channel-api.dart 10
# JavaScript ChannelPlate 23
# JavaScript testRunner 10
# JavaScript devtoolsExtended 73
# Go self-hosted-rss-to-email 29
# C zimu 6
# JavaScript tsviewdb 125
# 不明 beta-binomial-fitting 6
# 不明 wiberg-minimization 17
# JavaScript crx2app 22
# JavaScript concatenate.js 92
# Python firmata.py 21
# 不明 sirius 8
